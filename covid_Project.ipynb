# %% [markdown]
# <a href="https://colab.research.google.com/github/abhi1ranjan/covid19-modelling/blob/main/covid_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
import pandas as pd
import matplotlib.pyplot as plt

# %%
timeseries = pd.read_csv('COVID/timeseries.csv')

# %%
seroprevalanceData = pd.read_csv('COVID/seroprevalencedataNew.csv',index_col=0)
populationData = pd.read_csv('COVID/populationNew.csv')
populationData.set_index(['district'],inplace=True)
TotalTestData = pd.read_csv('COVID/testsNew.csv')
vaccinationsData = pd.read_csv('COVID/vaccinations.csv')
sero2 = pd.read_csv('COVID/serosurvey2.csv',index_col=0)

# %%
# sero2 = sero2.replace('Bengaluru Urban Conglomerate','Bengaluru Urban')
# for i in ['BBMP-Bommanahalli', 'BBMP-Dasarahalli', 'BBMP-East',
#        'BBMP-Mahadevpura', 'BBMP-RR-Nagar', 'BBMP-South', 'BBMP-West',
#        'BBMP-Yelahanka']:
#   temp = list(sero2[sero2.Unit=="Bengaluru Urban"].values[0])
#   temp[0] = i
#   sero2.loc[len(sero2.index),:] = temp
#   sero2.set_index(["Unit"],inplace=True)

# %%
# seroprevalanceData= seroprevalanceData.replace('Bagalkot','Bagalakote')
# seroprevalanceData= seroprevalanceData.replace('Belgaum','Belagavi')
# seroprevalanceData= seroprevalanceData.replace('Bengaluru-Rural','Bengaluru Rural')
# seroprevalanceData= seroprevalanceData.replace('Bengaluru-Urban','Bengaluru Urban')
# seroprevalanceData= seroprevalanceData.replace('Chamarajanagar','Chamarajanagara')
# seroprevalanceData= seroprevalanceData.replace('Chikkaballapur','Chikkaballapura')
# seroprevalanceData= seroprevalanceData.replace('Chikmagalur','Chikkamagaluru')
# seroprevalanceData= seroprevalanceData.replace('Dakshina-Kannada','Dakshina Kannada')
# seroprevalanceData= seroprevalanceData.replace('Uttara-Kannada','Uttara Kannada')
# seroprevalanceData= seroprevalanceData.replace('Ramanagar','Ramanagara')
# seroprevalanceData= seroprevalanceData.replace('BBMP Bommanahalli','BBMP-Bommanahalli')
# seroprevalanceData= seroprevalanceData.replace('BBMP Dasarahalli','BBMP-Dasarahalli')
# seroprevalanceData= seroprevalanceData.replace('BBMP East','BBMP-East')
# seroprevalanceData= seroprevalanceData.replace('BBMP Mahadevpura','BBMP-Mahadevpura')
# seroprevalanceData= seroprevalanceData.replace('BBMP RR Nagar','BBMP-RR-Nagar')
# seroprevalanceData= seroprevalanceData.replace('BBMP South','BBMP-South')
# seroprevalanceData= seroprevalanceData.replace('BBMP West','BBMP-West')
# seroprevalanceData= seroprevalanceData.replace('BBMP Yelahanka','BBMP-Yelahanka')
# seroprevalanceData.to_csv('COVID/seroprevalencedataNew.csv')

# %%
# sero2cir= sero2cir.replace('BBMP Bommanahalli','BBMP-Bommanahalli')
# sero2cir= sero2cir.replace('BBMP Dasarahalli','BBMP-Dasarahalli')
# sero2cir= sero2cir.replace('BBMP East','BBMP-East')
# sero2cir= sero2cir.replace('BBMP Mahadevpura','BBMP-Mahadevpura')
# sero2cir= sero2cir.replace('BBMP RR Nagar','BBMP-RR-Nagar')
# sero2cir= sero2cir.replace('BBMP South','BBMP-South')
# sero2cir= sero2cir.replace('BBMP West','BBMP-West')
# sero2cir= sero2cir.replace('BBMP Yelahanka','BBMP-Yelahanka')

# %%
# sero2cir.set_index(["Unit"],inplace=True)

# %%
# for i in districts:
#   TotalTestData[i] = TotalTestData['Daily Samples Tested'].apply(lambda x: x*populationData[populationData.district==i].perc)

# %%
# TotalTestData.to_csv('COVID/testsNew.csv')
# populationData.to_csv('COVID/populationNew.csv')

# %%
# populationData= populationData.replace('Bagalkot','Bagalakote')
# populationData= populationData.replace('Belgaum','Belagavi')
# populationData= populationData.replace('Bengaluru-Rural','Bengaluru Rural')
# populationData= populationData.replace('Bengaluru-Urban','Bengaluru Urban')
# populationData= populationData.replace('Chamarajanagar','Chamarajanagara')
# populationData= populationData.replace('Chikkaballapur','Chikkaballapura')
# populationData= populationData.replace('Chikmagalur','Chikkamagaluru')
# populationData= populationData.replace('Dakshina-Kannada','Dakshina Kannada')
# populationData= populationData.replace('Uttara-Kannada','Uttara Kannada')
# populationData= populationData.replace('Ramanagar','Ramanagara')
# populationData= populationData.replace('Yadgir','Yadgiri')
# populationData.district[-9:].values

# %%
# extra = ['BBMP-Bommanahalli', 'BBMP-Dasarahalli', 'BBMP-East',
#        'BBMP-Mahadevpura', 'BBMP-RR-Nagar', 'BBMP-South', 'BBMP-West',
#        'BBMP-Yelahanka', 'Bengaluru Urban']
# ratios = list(populationData.population[-9:] / populationData.population[-9:].sum())
# bu = pd.read_csv('COVID/dist/Bengaluru Urban.csv',index_col=0)
# for i in extra:
#   ind = extra.index(i)
#   new = bu.apply(lambda x: x*ratios[ind])
#   new.to_csv('COVID/dist/'+i+'.csv')

# %%
districts
# Out:
# ['BBMP-Bommanahalli',
#  'BBMP-Dasarahalli',
#  'BBMP-East',
#  'BBMP-Mahadevpura',
#  'BBMP-RR-Nagar',
#  'BBMP-South',
#  'BBMP-West',
#  'BBMP-Yelahanka',
#  'Bagalakote',
#  'Ballari',
#  'Belagavi',
#  'Bengaluru Rural',
#  'Bengaluru Urban',
#  'Bidar',
#  'Chamarajanagara',
#  'Chikkaballapura',
#  'Chikkamagaluru',
#  'Chitradurga',
#  'Dakshina Kannada',
#  'Davanagere',
#  'Dharwad',
#  'Gadag',
#  'Hassan',
#  'Haveri',
#  'Kalaburagi',
#  'Kodagu',
#  'Kolar',
#  'Koppal',
#  'Mandya',
#  'Mysuru',
#  'Raichur',
#  'Ramanagara',
#  'Shivamogga',
#  'Tumakuru',
#  'Udupi',
#  'Uttara Kannada',
#  'Vijayapura',
#  'Yadgiri']

# %%
# populationData['perc'] = populationData['population'].astype('int32')/populationData['population'].astype('int32').sum()

# %%
# #populationData['perc'] = populationData['population'].astype('int32')/populationData['population'].astype('int32').sum()
# for i in districts:
#   row = timeseries[timeseries['2']==i]
#   date = timeseries.iloc[1,2::3]
#   conf = row[timeseries.columns[range(2,len(timeseries.columns),3)]].values[0]
#   reco = row[timeseries.columns[range(3,len(timeseries.columns),3)]].values[0]
#   dece = row[timeseries.columns[range(4,len(timeseries.columns),3)]].values[0]
#   data = pd.DataFrame({'Confirmed':conf,'Recovered':reco,'Deceased':dece},index=date)
#   data.loc[vaccinationsData.columns[2:222],'First'] = vaccinationsData[vaccinationsData.district==i].values[0][2:222]
#   data.to_csv('COVID/dist/'+i+'.csv')

# %%
"""
infTime-  infected people timeseries data
recTime-  Recovered people timeseries data
decTime-  deceased people timeseries data
"""

infTime = timeseries[timeseries.columns[range(2,len(timeseries.columns),3)]]
infTime.columns = infTime.iloc[1,:]
infTime = infTime.iloc[2:,:]
infTime.index = timeseries['2'][2:].values

# %%
recTime = timeseries[timeseries.columns[range(3,len(timeseries.columns),3)]]
recTime.columns = recTime.iloc[1,:]
recTime = recTime.iloc[2:,:]
recTime.index = timeseries['2'][2:].values

# %%
decTime = timeseries[timeseries.columns[range(4,len(timeseries.columns),3)]]
decTime.columns = decTime.iloc[1,:]
decTime = decTime.iloc[2:,:]
decTime.index = timeseries['2'][2:].values

# %%
#infTime.T.rolling(7,min_periods=1).mean().T

# %%
districts = list(timeseries['2'])[2:-2] + ['BBMP-Bommanahalli', 'BBMP-Dasarahalli', 'BBMP-East',
       'BBMP-Mahadevpura', 'BBMP-RR-Nagar', 'BBMP-South', 'BBMP-West',
       'BBMP-Yelahanka']#, 'Bengaluru Urban']
districts.sort()

# %%
mainData = {}
for i in districts:
  mainData[i] = pd.read_csv('COVID/dist/'+i+'.csv',index_col=0).replace(np.nan,0)
  mainData[i]["ConfirmedDaily"] = mainData[i]["Confirmed"]
  mainData[i].loc[mainData[i].index[1:],"ConfirmedDaily"] = mainData[i]["ConfirmedDaily"].values[1:]-mainData[i]["ConfirmedDaily"].values[:-1]
  mainData[i]['ConfirmedRoll'] = mainData[i]['ConfirmedDaily'].rolling(7,min_periods=1).mean()
  mainData[i]['TestRoll'] = mainData[i]['Test'].rolling(7,min_periods=1).mean()
  mainData[i]['FirstRoll'] = mainData[i]['First'].rolling(7,min_periods=1).mean()
  mainData[i]['Active'] = mainData[i]['Confirmed'] - mainData[i]['Recovered'] - mainData[i]['Deceased']
  mainData[i]['ActiveRoll'] = mainData[i]['Active'].rolling(7,min_periods=1).mean()

# %%
recCases = []
for i in districts:
  recCases.append(mainData[i].loc['01-11-2020','Recovered']+mainData[i].loc['01-11-2020','Deceased'])
activeCases = []
for i in districts:
  activeCases.append(mainData[i].loc['01-11-2020','ActiveRoll'])
expoCases = []
for i in districts:
  expoCases.append(mainData[i].loc[['02-11-2020','03-11-2020','04-11-2020','05-11-2020','06-11-2020'],'ConfirmedRoll'].sum())
recCases,activeCases,expoCases

# %%
start_date = '01-11-2020'#'01-11-2020'#'11-10-2020'
end_date = '28-02-2021'#'28-02-2021'#'01-11-2020'
datesFull = list(mainData['BBMP-West'].index)
datesUsed = datesFull[datesFull.index(start_date):datesFull.index(end_date)+1]
datesLen = datesFull.index(end_date) - datesFull.index(start_date) + 1

# %%
testData = []
for i in districts:
  testData.append(list(mainData[i].loc[datesUsed,'TestRoll']))
testData = np.array(testData).T

# %%
testData

# %%
conData = []
for i in districts:
  conData.append(list(mainData[i].loc[datesUsed,'ConfirmedRoll']))
conData = np.array(conData).T

# %%
vacData = []
for i in districts:
  vacData.append(list(mainData[i].loc[datesUsed,'FirstRoll']))
vacData = np.array(vacData).T

# %%
date = '01-11-2020'#'15-03-2021'
Reported_Cases_On_1_Nov = []
for i in districts:
  Reported_Cases_On_1_Nov.append(mainData[i].loc[date,'ConfirmedRoll'].astype('int32'))

# %%
cirList = []
for i in districts:
  cirList.append(seroprevalanceData.loc[i,"CIR"]* mainData[i].loc['11-10-2020',"TestRoll"] / mainData[i].loc['01-11-2020',"TestRoll"])
cirList

# %%
I0 = np.array(activeCases)/2*np.array(cirList)
E0 = np.array(expoCases)/2*np.array(cirList)
R0 = np.array(recCases)/2*np.array(cirList)
S0  = N- (I0+E0+R0)
CIR0 = cirList

# %%
E0
# Out:
# array([ 8497.93894,  2981.34081, 17367.44224,  5508.12363,  7656.48982,
#        32091.94632, 13691.10375,  3105.7885 ,  1807.93633,  8588.41973,
#        10109.28166,  7674.73148,  5064.34263,   989.34098,  5092.85756,
#         3875.85572,  6846.6893 , 13610.85545,  8834.11544,  7875.53522,
#         1278.83565,   498.418  , 15606.16696,  3732.51371,  5836.73705,
#         3213.48444,  8466.39164,  2103.44261, 13579.54818, 13644.03647,
#         3815.27108,  4135.68265,  4869.56879, 25134.19517,  4273.7157 ,
#         4395.35343, 21370.76456,  2918.83696])

# %%
# seroprevalanceData['E0'] = 0.9*seroprevalanceData['Active']
# seroprevalanceData['I0'] = 0.1*seroprevalanceData['Active']
# seroprevalanceData.columns = ['Samples', 'R0', 'Active', 'Prevalence', 'CIR', 'IFR', 'E0', 'I0']
# seroprevalanceData['S0'] = 100 -seroprevalanceData['R0'] - seroprevalanceData['E0'] - seroprevalanceData['I0']
# seroprevalanceData

# %%
# for i in districts:
#   data = pd.read_csv('COVID/dist/'+i+'.csv',index_col=0).replace(np.nan,0)
#   #print(data)
#   #print(data.loc[TotalTestData.index[10:-1],'First'])
#   ind = list(TotalTestData.columns).index(i)
#   #print(TotalTestData.values[10:-1,ind].shape)
#   data.loc[TotalTestData.index[10:-1],'Test'] = TotalTestData.values[10:-1,ind]
#   print(data)
#   data.to_csv('COVID/dist/'+i+'.csv')

# %%
N = list(populationData.loc[districts,"population"].values)   #total unit-wise population

# %%
temp = seroprevalanceData.loc[districts,['S0','E0','I0','R0','CIR']].values.T
S0,E0,I0,R0,CIR0 = list(temp[0]),list(temp[1]),list(temp[2]),list(temp[3]),list(temp[4])

# %%
def weibull(t,scale=120,shape=3.67):
  normalization = (shape / scale) * math.pow( (t / scale) , shape - 1 )
  exponent = math.pow( t/scale , shape )
  return normalization*math.exp( -1*exponent )

# %%
weibull(0 , 130 , 3.67)
# Out:
# 0.0

# %%
V0 = []
for i in range(38):
  S0[i] = S0[i] * N[i] / 100
  E0[i] = E0[i] * N[i] / 100
  I0[i] = I0[i] * N[i] / 100
  R0[i] = R0[i] * N[i] / 100
  V0.append(0)

# %%
print(Reported_Cases_On_1_Nov)

for i in range(len(Reported_Cases_On_1_Nov)):
  Reported_Cases_On_1_Nov[i]/=2

print(Reported_Cases_On_1_Nov)
# Out:
# [180, 87, 331, 175, 146, 383, 249, 107, 27, 67, 41, 74, 175, 7, 29, 62, 48, 73, 114, 66, 41, 15, 126, 26, 36, 29, 51, 20, 90, 160, 21, 19, 60, 100, 57, 55, 83, 16]
# [90.0, 43.5, 165.5, 87.5, 73.0, 191.5, 124.5, 53.5, 13.5, 33.5, 20.5, 37.0, 87.5, 3.5, 14.5, 31.0, 24.0, 36.5, 57.0, 33.0, 20.5, 7.5, 63.0, 13.0, 18.0, 14.5, 25.5, 10.0, 45.0, 80.0, 10.5, 9.5, 30.0, 50.0, 28.5, 27.5, 41.5, 8.0]

# %%
## parameters is of order
## beta, St, Et, It, Rt, CIRt, M , dVt, dWt, N

def Next_Instant_Values(parameters):
  beta = parameters[0]    ## List of Beta values for all the units - For all the List the size should be 38 X 1
  St = parameters[1]      ## List for all units - Susceptible at time t
  Et = parameters[2]      ## List for all units - Exposed at time t
  It = parameters[3]      ## List for all units - Infection at time t
  Rt = parameters[4]      ## List for all units - Recovered at time t
  CIRt = parameters[5]    ## List for all units - CIR rate at time t. We can take it as a constant - also we can vary it using number of tests
  M = parameters[6]       ## This is the mobility Matrix - This should be of 38 X 38
  dVt = parameters[7]     ## List for all units - Number of vaccinations done on the current date
  dWt = parameters[8]     ## List for all units - Number of Waned population at current time
  N = parameters[9]       ## List for all units - Number of peoples 
  Vt = parameters[10]     ## List for all units - Vaccination % at time t -- Currently we are not using it

  epsilon = 0.66 ## Vaccination Efficiency
  alpha = 1 / 5.8 ## Rate from Expose to Infection
  gamma = 1 / 5 ## Rate from Infectioin to Recovered

  Snext = []
  Enext = []
  Inext = []
  Rnext = []
  Vnext = []

  for i in range(38):
    ## This is for this unit
    d1 = alpha * Et[i]
    d2 = gamma * It[i]
    d3 = epsilon * dVt[i]
    d4 = 0

    for j in range(38):
      d4 += M[i][j] * It[j] / N[j]
    
    d4 *= St[i] * beta[i]

    ## These are the differences

    snext = int( St[i] - d4 - d3 + dWt[i] )
    enext = int( Et[i] + d4  - d1 )
    inext = int( It[i] + d1 - d2 )
    rnext = int( Rt[i] + d2 - dWt[i] )
    vnext = int( Vt[i] + d3 )

    Snext.append(snext)
    Enext.append(enext)
    Inext.append(inext)
    Rnext.append(rnext)
    Vnext.append(vnext)
  
  return ( Snext , Enext , Inext , Rnext , Vnext )

# %%
def Loss1(parameters,index):
  beta = parameters[0]    ## List of Beta values for all the units - For all the List the size should be 38 X 1
  S0 = parameters[1]      ## List for all units - Susceptible at time t
  E0 = parameters[2]      ## List for all units - Exposed at time t
  I0 = parameters[3]      ## List for all units - Infection at time t
  R0 = parameters[4]      ## List for all units - Recovered at time t
  CIR0 = parameters[5]    ## List for all units - CIR rate at time t. We can take it as a constant - also we can vary it using number of tests
  M = parameters[6]       ## This is the mobility Matrix - This should be of 38 X 38
  N = parameters[7]       ## List for all units - Number of peoples 
  V0 = parameters[8]      ## List for all units - Vaccination % at time t -- Currently we are not using it
  scale = parameters[9]
  shape = parameters[10]

  epsilon = 0.66 ## Vaccination Efficiency
  alpha = 1 / 5.8 ## Rate from Expose to Infection
  gamma = 1 / 5 ## Rate from Infectioin to Recovered

  S21days = [S0]
  E21days = [E0]
  I21days = [I0]
  R21days = [R0]
  V21days = [V0]
  CIR21days = [CIR0]

  delta_R = [R0]

  ## dVt and dWt we will get from the timeseries data and function respectively

  days = 21 ## From 11Oct - 31Oct and 1 Nov

  for i in range(21):
    
    '''
      Compute CIR if it is dynamic. Otherwise keep it constant
    '''

    ## print("Day = " , i)

    CIRcur = CIR21days[i]
    
    Scur = S21days[i]
    Ecur = E21days[i]
    Icur = I21days[i]
    Rcur = R21days[i]
    Vcur = V21days[i]

    delta_V = np.zeros(38)
    delta_W = []

    for j in range(38):
      k = i
      wane_population = 0
      while (k >= 0):
        wane_population += delta_R[k][j]*(weibull(i - k + 1 , scale , shape))
        k-=1
      delta_W.append(wane_population)


    Snext, Enext, Inext, Rnext, Vnext = Next_Instant_Values( (beta, Scur, Ecur, Icur, Rcur, CIRcur, M, delta_V, delta_W, N, Vcur) )

    S21days.append(Snext)
    E21days.append(Enext)
    I21days.append(Inext)
    R21days.append(Rnext)
    V21days.append(Vnext)

    CIRnext = []

    for j in range(38):
      val = CIR0[j] * (testData[0][j] / testData[i][j])
      CIRnext.append(val)

    CIR21days.append(CIRnext)

    delta_R_cur = []

    for j in range(38):
      delta_R_cur.append(Rnext[j] - Rcur[j])

    delta_R.append(delta_R_cur) ## These are the people who went to recovered this day
  
  ## After calculating the 21days values we have to find the loss
  ## Reported_Cases_On_1_Nov = [] ## Find out this from the time series data
  Predicted_Case_On_1_Nov = []

  '''
    For finding the Predicted cases on 1Nov we have to take running avg of past 7 days alpha * e
  '''
  for i in range(38):
    val = 0
    for j in range(7):
      val += alpha * (E21days[-1*j - 1][i] / CIR21days[-1*j - 1][i])
    val /= 7
    Predicted_Case_On_1_Nov.append(val)
  
  ## Now compute the loss
  loss = 0.0
  
  # for i in range(38):
  #   diff = abs( Reported_Cases_On_1_Nov[i] - Predicted_Case_On_1_Nov[i] ) / Reported_Cases_On_1_Nov[i]
  #   loss = max(loss , diff)
  loss = abs( Reported_Cases_On_1_Nov[index] - Predicted_Case_On_1_Nov[index] ) / Reported_Cases_On_1_Nov[index]
    
  
  # print(loss)
  # print(Reported_Cases_On_1_Nov)
  # print(Predicted_Case_On_1_Nov)

  #assert(1 == 2)

  return loss

# %%
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ## It should take the initial parameters and return the converged parameters

def gradient_descent1(parameters):
  beta = parameters[0]
  scale = parameters[1] ## This is the weibull scale parameter
  shape = parameters[2] ## This is the weibull shape parameter

  ## Below values are to be gotten from the seroprevalence data and timeseries data
  '''
  S0 = []
  E0 = []
  I0 = []
  R0 = []
  V0 = []
  CIR0 = []
  N = []
  '''
  M = np.identity(38)   ## This is because for this task the mobility is Identity

  ## We have to change the beta values as 0.01, scale values as 1 and shape values as 0.01

  iter = 0

  min_loss = 100000000.0
  min_parameters = (beta , scale , shape)


  while (True):

    print(" _______________ iteration " , iter , " is starting _____________ ")
    iter+=1

    print(min_parameters)

    iter_parameters = min_parameters

    changed = False

    changes = [0.2 , 1, 0.01] ## First one is for the beta, second for the scale and last for the shape

    ## First lets change the beta values
    for i in range(38):
      ## print(i)
      beta_cur_pos = iter_parameters[0]
      beta_cur_neg = iter_parameters[0]
      beta_cur_pos[i] += changes[0]
      beta_cur_neg[i] -= changes[0]

      ## print("I am here")
      Beta_pos_val = Loss1( (beta_cur_pos, S0, E0, I0, R0, CIR0, M, N, V0, iter_parameters[1], iter_parameters[2]) )
      ## print("I am here")
      Beta_neg_val = Loss1( (beta_cur_neg, S0, E0, I0, R0, CIR0, M, N, V0, iter_parameters[1], iter_parameters[2]) )
      ## print("I am here")

      if (Beta_pos_val < min_loss):
        min_loss = Beta_pos_val
        min_parameters = (beta_cur_pos , scale , shape)
        changed = True
      
      if (Beta_neg_val < min_loss):
        min_loss = Beta_neg_val
        min_parameters = (beta_cur_neg , scale , shape)
        changed = True
    
    ## Now lets change the scale
    Scale_pos_val = Loss1( (iter_parameters[0], S0, E0, I0, R0, CIR0, M, N, V0, iter_parameters[1] + changes[1] , iter_parameters[2]) )
    Scale_neg_val = Loss1( (iter_parameters[0], S0, E0, I0, R0, CIR0, M, N, V0, iter_parameters[1] - changes[1] , iter_parameters[2]) )

    if (Scale_pos_val < min_loss):
      min_loss = Scale_pos_val
      min_parameters = ( iter_parameters[0] , iter_parameters[1] + changes[1] , iter_parameters[2] )
      changed = True
    
    if (Scale_neg_val < min_loss):
      min_loss = Scale_neg_val
      min_parameters = ( iter_parameters[0] , iter_parameters[1] - changes[1] , iter_parameters[2] )
      changed = True
    
    ## Now lets change the shape
    Shape_pos_val = Loss1( (iter_parameters[0], S0, E0, I0, R0, CIR0, M, N, V0, iter_parameters[1] , iter_parameters[2] + changes[2] ) )
    Shape_neg_val = Loss1( (iter_parameters[0], S0, E0, I0, R0, CIR0, M, N, V0, iter_parameters[1] , iter_parameters[2] - changes[2] ) )

    if (Shape_pos_val < min_loss):
      min_loss = Shape_pos_val
      min_parameters = ( iter_parameters[0] , iter_parameters[1] , iter_parameters[2] + changes[2]  )
      changed = True
    
    if (Shape_neg_val < min_loss):
      min_loss = Shape_neg_val
      min_parameters = ( iter_parameters[0] , iter_parameters[1] , iter_parameters[2] - changes[2]  )
      changed = True
    
    print("Loss in this iteration = " , min_loss)

    ## assert(1 == 2)

    if(changed == False):
      print("Gradient is not going down so exiting")
      break

# %%
beta = [0.03 for i in range(38)]
scale = 120
shape = 3.67

gradient_descent1( (beta , scale , shape) )

# %%
def dummyloss(x): 
  M = np.identity(38)
  return Loss1( (x[:38], S0, I0, E0, R0, CIR0, M, N, V0, x[38], x[39]))

# %%
from scipy.optimize import minimize,brute
x0 = 0.1 * np.ones(40)
x0[38]=105
x0[39]=2.6
bounds = [(0,1) for _ in range(38)]
bounds.append((110,140))
bounds.append((3,5))
bounds = tuple(bounds)
res = minimize(dummyloss, x0, method='Nelder-Mead')#,bounds=bounds)
# for index in range(38):
#   res = brute(dummyloss,((0,1)),(index))
#   print(res)

# %%
def dummyloss(x,index): 
  M = np.identity(38)#np.identity(38)*0.99 + np.ones((38,38))*0.01
  x0 = 0.1 * np.ones(38)
  x0[index] = x[0]
  return Loss1( (x0, S0, I0, E0, R0, CIR0, M, N, V0, x[1], x[2]),index)

# %%
def dummyloss2(x,index): 
  M = np.identity(38)
  x0 = 0.1 * np.ones(38)
  x0[index[0]] = x
  return Loss1( (x0, S0, I0, E0, R0, CIR0, M, N, V0, index[1], index[2]),index[0])

# %%
from scipy.optimize import minimize,brute
x0 = 0.1 * np.ones(3)
x0[1]=150
x0[2]=6
bounds = [(0,1) for _ in range(1)]
bounds.append((10,200))
bounds.append((3,5))
bounds = tuple(bounds)
ans = []
forCSV = []
for index in range(38):

  try:
    res = minimize(dummyloss, x0,index,tol=0.1, method='Nelder-Mead')#,bounds=bounds)#'Nelder-Mead'
    print(res.fun,res.x)
    ans.append(res.x)
    forCSV.append([res.fun,res.x[0],res.x[1],res.x[2]])
  except:
    res = minimize(dummyloss2, 0.42,[index,104.57,2.94],tol=0.1, method='Nelder-Mead')#,bounds=bounds)#'Nelder-Mead'
    print(res.fun,res.x)
    ans.append([res.x[0],104.57,2.94])
    forCSV.append([res.fun,res.x[0],104.57,2.94])
# for index in range(38):
#   res = brute(dummyloss,((0,1)),(index))
#   print(res)
#0.45+ for district 6
#0.28 for district 6
# Out:
# 1.408743825095371e-05 [9.08025035e-02 1.56791617e+02 6.15928414e+00]
# 0.00010975715689868458 [1.10803211e-01 1.43174705e+02 5.69318689e+00]
# 0.05563378953818977 [0.357]
# 0.0003290564879258844 [8.59955827e-02 1.56727987e+02 6.18202266e+00]
# 0.00019309642244777074 [8.76340464e-02 1.57145437e+02 6.21983515e+00]
# 0.00011057985585857299 [ 0.19028939 77.42622126  2.80234667]
# 0.0003958738677383452 [  0.14691084 121.06105742   4.3073773 ]
# 8.435038720112673e-05 [1.08005895e-01 1.44152081e+02 5.71214072e+00]
# 0.0007170608138494835 [1.49551691e-02 1.85346394e+02 7.01332642e+00]
# 0.0009348615123738017 [2.71821443e-02 1.78806320e+02 6.86302439e+00]
# 3.1021382949243774e-05 [5.31400301e-02 1.68626671e+02 6.58120477e+00]
# 0.00017923219429956657 [8.22915557e-02 1.55969121e+02 6.27819436e+00]
# 6.499192258031274e-05 [7.52623699e-02 1.56647805e+02 6.39466559e+00]
# 0.0001951306838961894 [1.01031163e-01 1.52167539e+02 5.90031133e+00]
# 1.3082496589064397e-05 [9.89156503e-02 1.53078400e+02 5.96800429e+00]
# 0.00023139219368100008 [7.08278265e-02 1.62990921e+02 6.47397335e+00]
# 0.00016859364054525963 [5.51270894e-02 1.66575083e+02 6.61170213e+00]
# 0.0002991339213052666 [8.58730232e-02 1.56706019e+02 6.18499688e+00]
# 0.00037513965614303853 [5.61915077e-02 1.66666103e+02 6.61253132e+00]
# 0.000378945073834278 [4.33903784e-02 1.68995381e+02 6.82159937e+00]
# 0.0011468314662971026 [4.45715459e-02 1.70270284e+02 6.72971339e+00]
# 0.0013797381541727086 [2.51534156e-02 1.79872202e+02 6.83897784e+00]
# 0.0002124490506650955 [7.13892061e-02 1.62704567e+02 6.46008152e+00]
# 0.0002070195428327537 [3.55431904e-02 1.70436447e+02 6.81387792e+00]
# 9.451269562236557e-05 [2.46898559e-02 1.80064275e+02 6.83395759e+00]
# 9.27380645665784e-05 [1.06327914e-01 1.47976894e+02 5.84881727e+00]
# 0.00024641783038986784 [8.56516350e-02 1.56699589e+02 6.19028381e+00]
# 0.00010993913406434074 [6.96885932e-02 1.63091120e+02 6.47758781e+00]
# 0.00023462000773359173 [1.24676264e-01 1.34394311e+02 5.12369792e+00]
# 0.00012149915169761272 [7.83406142e-02 1.60126529e+02 6.25794041e+00]
# 0.00023911802373076187 [3.15744241e-02 1.77214965e+02 6.84458271e+00]
# 0.0004943319772034876 [3.85661079e-02 1.71047329e+02 6.63668290e+00]
# 0.00020854823051680665 [3.17106476e-02 1.77091413e+02 6.83720372e+00]
# 0.0009031113152380499 [5.82912140e-02 1.66574245e+02 6.59427604e+00]
# 0.00011589274008122972 [3.75651815e-02 1.70438498e+02 6.65998461e+00]
# 0.0002510775727035831 [5.25465538e-02 1.69767424e+02 6.58374656e+00]
# 0.00012231065748202093 [1.18301079e-01 1.38578898e+02 5.46695113e+00]
# 0.0018950185665662644 [1.82533653e-02 1.84224768e+02 6.90389304e+00]

# %%
#forCSV#=np.array(forCSV)
temp = pd.DataFrame(forCSV)
temp.columns = ["Error","Beta","Scale","Shape"]
temp.to_csv('COVID/plots/1/res.csv')

# %%
temp

# %%
def vis(parameters,index):
  beta = parameters[0]    ## List of Beta values for all the units - For all the List the size should be 38 X 1
  S0 = parameters[1]      ## List for all units - Susceptible at time t
  E0 = parameters[2]      ## List for all units - Exposed at time t
  I0 = parameters[3]      ## List for all units - Infection at time t
  R0 = parameters[4]      ## List for all units - Recovered at time t
  CIR0 = parameters[5]    ## List for all units - CIR rate at time t. We can take it as a constant - also we can vary it using number of tests
  M = parameters[6]       ## This is the mobility Matrix - This should be of 38 X 38
  N = parameters[7]       ## List for all units - Number of peoples 
  V0 = parameters[8]      ## List for all units - Vaccination % at time t -- Currently we are not using it
  scale = parameters[9]
  shape = parameters[10]

  epsilon = 0.66 ## Vaccination Efficiency
  alpha = 1 / 5.8 ## Rate from Expose to Infection
  gamma = 1 / 5 ## Rate from Infectioin to Recovered

  S21days = [S0]
  E21days = [E0]
  I21days = [I0]
  R21days = [R0]
  V21days = [V0]
  CIR21days = [CIR0]
  Predicted_Case = []

  delta_R = [R0]

  ## dVt and dWt we will get from the timeseries data and function respectively

  days = 21 ## From 11Oct - 31Oct and 1 Nov

  for i in range(21):
    
    '''
      Compute CIR if it is dynamic. Otherwise keep it constant
    '''

    ## print("Day = " , i)

    CIRcur = CIR21days[i]
    
    Scur = S21days[i]
    Ecur = E21days[i]
    Icur = I21days[i]
    Rcur = R21days[i]
    Vcur = V21days[i]

    

    delta_V = np.zeros(38)
    delta_W = []

    for j in range(38):
      k = i
      wane_population = 0
      while (k >= 0):
        wane_population += delta_R[k][j]*(weibull(i - k + 1 , scale , shape))
        k-=1
      delta_W.append(wane_population)


    Snext, Enext, Inext, Rnext, Vnext = Next_Instant_Values( (beta, Scur, Ecur, Icur, Rcur, CIRcur, M, delta_V, delta_W, N, Vcur) )

    S21days.append(Snext)
    E21days.append(Enext)
    I21days.append(Inext)
    R21days.append(Rnext)
    V21days.append(Vnext)
    
    CIRnext = []

    for j in range(38):
      val = CIR0[j] * (testData[0][j] / testData[i][j])
      CIRnext.append(val)

    CIR21days.append(CIRnext)


    delta_R_cur = []

    for j in range(38):
      delta_R_cur.append(Rnext[j] - Rcur[j])

    delta_R.append(delta_R_cur) ## These are the people who went to recovered this day
    Predicted_Case_On_1_Nov = []

    for i in range(38):
      Predicted_Case_On_1_Nov.append(alpha * (E21days[- 1][i] / CIR21days[- 1][i]))
    Predicted_Case.append(Predicted_Case_On_1_Nov)
  S21days = np.array(S21days)
  E21days = np.array(E21days)
  I21days = np.array(I21days)
  R21days = np.array(R21days)
  Predicted_Case = np.array(Predicted_Case)
  # plt.plot(S21days.T[index],label='S')
  # plt.plot(E21days.T[index],label='E')
  # plt.plot(I21days.T[index],label='I')
  # plt.plot(R21days.T[index],label='R')
  # # plt.plot(Predicted_Case.T[index],label = 'Predicted')
  # # plt.plot(conData[1:,index]/2,label = 'True')
  # #plt.plot(S21days.T[index] + E21days.T[index] + I21days.T[index] + R21days.T[index],label = 'Sum')
  # plt.legend()
  # plt.title(districts[index])
  # #plt.savefig('COVID/plots/1/'+districts[index]+'SEIR.png')
  # plt.show()
  return S21days[-1],E21days[-1],I21days[-1],R21days[-1]

# %%
for index in range(38):
  x0 = 0.1 * np.ones(38)
  M = np.identity(38)
  x0[index] = ans[index][0]
  #print(Loss1((x0, S0, I0, E0, R0, CIR0, M, N, V0, ans[index][1],   ans[index][2]),index))
  S0,E0,I0,R0 = vis( (x0, S0, I0, E0, R0, CIR0, M, N, V0, ans[index][1],   ans[index][2]),index)

# %%
V0

# %%
## This loss function will be used for the second task
def Loss2(parameters,index):
  beta = parameters[0]    ## List of Beta values for all the units - For all the List the size should be 38 X 1
  S0 = parameters[1]      ## List for all units - Susceptible at time t
  E0 = parameters[2]      ## List for all units - Exposed at time t
  I0 = parameters[3]      ## List for all units - Infection at time t
  R0 = parameters[4]      ## List for all units - Recovered at time t
  CIR0 = parameters[5]    ## List for all units - CIR rate at time t. We can take it as a constant - also we can vary it using number of tests
  M = parameters[6]       ## This is the mobility Matrix - This should be of 38 X 38
  N = parameters[7]       ## List for all units - Number of peoples 
  V0 = parameters[8]      ## List for all units - Vaccination % at time t -- Currently we are not using it

  # print(E0)
  # assert(1 == 2)

  epsilon = 0.66 ## Vaccination Efficiency
  alpha = 1 / 5.8 ## Rate from Expose to Infection
  gamma = 1 / 5 ## Rate from Infectioin to Recovered

  ## 1 Nov 2020 to 28 feb. As we have the data for 1 Nov we have to project 119 days more

  S119days = [S0]
  E119days = [E0]
  I119days = [I0]
  R119days = [R0]
  V119days = [V0]
  CIR119days = [CIR0]

  delta_R = [R0]

  ## dVt and dWt we will get from the timeseries data and function respectively

  days = 119 ## From 1 Nov 2020 to 28 feb

  for i in range(days):
    
    CIRcur = CIR119days[i]
    Scur = S119days[i]
    Ecur = E119days[i]
    Icur = I119days[i]
    Rcur = R119days[i]
    Vcur = V119days[i]

    delta_V = vacData[i] ## This we will get from  the data. This is for 38 units
    delta_W = []

    for j in range(38):
      k = i
      wane_population = 0
      while (k >= 0):
        wane_population += delta_R[k][j]*(weibull(i - k + 1 , scale , shape))
        k-=1
      delta_W.append(wane_population)


    Snext, Enext, Inext, Rnext, Vnext = Next_Instant_Values( (beta, Scur, Ecur, Icur, Rcur, CIRcur, M, delta_V, delta_W, N, Vcur) )

    S119days.append(Snext)
    E119days.append(Enext)
    I119days.append(Inext)
    R119days.append(Rnext)
    V119days.append(Vnext)
    delta_R_cur = []

    for j in range(38):
      delta_R_cur.append(Rnext[j] - Rcur[j])

    delta_R.append(delta_R_cur)

    CIRnext = []

    for j in range(38):
      val = CIR0[j] * (testData[0][j] / testData[i+1][j])
      CIRnext.append(val)

    CIR119days.append(CIRnext)
  
  ## Now we have the S,E,I,R values for all the units and for all days from 1 Nov to 28 Feb
  ## Now we will calculate the loss for all units. And we will take the maximum loss
  ## For that i have to calculate the e bar t

  Reported_Cases_Daily = conData ## This we will get from the timeseries data. This should be of size 38X120


  alpha_e_t = [] ## This has the size 38 X 120

  for i in range(38):
    alpha_e_t_unitwise = []
    for j in range(120):
      alpha_e_t_unitwise.append( alpha * E119days[j][i] / CIR119days[j][i] )
    alpha_e_t.append(alpha_e_t_unitwise)
  
  ## We have to take rolling average of the above data

  alpha_e_bar = []

  for i in range(38):
    alpha_e_bar_unitwise = []
    for j in range(120):
      sum = 0
      count = 0
      for k in range(7):
        if(j-k < 0):
          break
        sum += alpha_e_t[i][j-k]
        count+=1
      alpha_e_bar_unitwise.append( sum / count)
    alpha_e_bar.append(alpha_e_bar_unitwise)

  ## Now we have our prediction of daily for each unit
  ## Now we will calcualte the loss for each unit.

  loss_all_unit = [] ## This will store the loss for all the units
  loss = 0.0 ## This will store the maximum error among the units

  #for i in range(38):
  if True:
    loss_per_unit = 0.0
    for j in range(120):
      ## print(Reported_Cases_Daily[j][i],alpha_e_bar[i][j])
      loss_per_unit += ( math.log( Reported_Cases_Daily[j][index] +0.0001) - math.log( alpha_e_bar[index][j] )+0.0001 )**2
    ## Also we have to match it to serosurvey data
    ## So, i have to add it to the loss
    loss_per_unit/=120
    #print(loss_per_unit)

    e_i_mix_frac = (E119days[-1][index] + I119days[-1][index]) / N[index]
    r_frac = (R119days[-1][index]) / N[index]
    ## print(sero2.loc[districts[i],"Infection"])
    loss_per_unit += (sero2.loc[districts[index],"Infection"] - e_i_mix_frac)**2 + (sero2.loc[districts[index],"Recovered"] - r_frac)**2
    loss_all_unit.append(loss_per_unit)
    #print(loss_per_unit)
    #loss = max(loss , loss_per_unit)
  #print(loss_per_unit)
  return loss_per_unit

# %%
def dummyloss(x,index): 
  M = np.identity(38)
  return Loss2( (x[:38], S0, I0, E0, R0, CIR0, M, N, V0, x[38], x[39]))

# %%
def dummyloss(x,index): 
  M = np.identity(38)#np.identity(38)*0.99 + np.ones((38,38))*0.01
  x0 = 0.1 * np.ones(38)
  x0[index] = x[0]
  return Loss2( (x0, S0, E0, I0, R0, CIR0, M, N, V0, x[1], x[2]),index)

# %%
def dummyloss2(x,index): 
  M = np.identity(38)
  x0 = 0.1 * np.ones(38)
  x0[index[0]] = x
  return Loss2( (x0, S0, E0, I0, R0, CIR0, M, N, V0, index[1], index[2]),index[0])

# %%
from scipy.optimize import minimize,brute
x0 = 0.20 * np.ones(3)
x0[1]=120
x0[2]=3.67 
ans = []
forCSV = []
for index in range(38):
  res = minimize(dummyloss, x0,index, method='Nelder-Mead')#,bounds=bounds)
  print(res.fun,res.x)
  ans.append(res.x)
  forCSV.append([res.fun,res.x[0],res.x[1],res.x[2]])
# for index in range(38):
#   res = brute(dummyloss,((0.001,1),(110,130),(3,4)),[index])
#   print(res)
# Out:
# 0.20075458852432085 [  0.25083 107.6442    3.12462]
# 0.19678247689432882 [  0.2152  117.33243   3.44532]
# 0.20600411620016304 [  0.26866 103.10789   2.92904]
# 0.1951728507586444 [  0.20925 119.67574   3.61433]
# 0.20684715994410333 [  0.26906 100.81604   2.94527]
# 0.3470650435107239 [ 0.47475 46.62717  0.84422]
# 0.2103331919291473 [ 0.27879 99.44955  2.73699]
# 0.1969488923468703 [  0.2033  121.60889   3.55326]
# 0.30040975770140776 [  0.16696 122.97555   3.81478]
# 0.1651128824244584 [  0.22041 114.92316   3.48844]
# 0.05132766852073145 [  0.23313 111.21737   3.40738]
# 0.37589256654962433 [  0.25681 102.94401   3.05811]
# 0.19617407349741245 [  0.20401 121.92469   3.61244]
# 0.15370565240333486 [  0.23539 111.30445   3.35024]
# 0.15118528276998722 [  0.21791 114.23067   3.5098 ]
# 0.13336863939494398 [  0.20752 121.51545   3.56264]
# 0.08828154983401323 [  0.24581 103.59973   3.11807]
# 0.0981684899128447 [ 0.27064 99.94375  2.92017]
# 0.2863322351344771 [  0.22985 116.09932   3.33652]
# 0.0970404534684281 [  0.24424 105.88213   3.20986]
# 0.1597277709308679 [  0.18004 124.78281   3.83382]
# 0.10011021522823765 [  0.17373 126.26625   3.80771]
# 0.08470956413615618 [  0.25158 107.60542   3.11054]
# 0.4509669566275275 [  0.18717 123.2271    3.73445]
# 0.10285288741781592 [  0.23928 109.36444   3.30638]
# 0.16346502355362624 [  0.26799 100.39275   2.9346 ]
# 0.1311467367613795 [  0.20102 120.20629   3.69837]
# 0.3080374614755087 [  0.16537 123.40216   3.82427]
# 0.1309759092121744 [  0.21778 114.29823   3.50827]
# 0.10914775666511989 [  0.23979 109.11833   3.29218]
# 0.15863050806816545 [  0.2094  119.34309   3.58783]
# 0.1768726553685434 [  0.19404 124.54634   3.66341]
# 0.15388996480677436 [  0.19789 121.67363   3.60084]
# 0.1668610715348357 [ 0.27891 99.67678  2.73347]
# 0.3509977689809734 [  0.24178 107.89861   3.27397]
# 0.11151382545102308 [  0.19213 124.19265   3.66606]
# 0.14446260453632562 [  0.23753 110.31759   3.32098]
# 0.1378371269412857 [  0.20268 122.94525   3.60218]

# %%
forCSV=np.array(forCSV)
temp = pd.DataFrame(forCSV)
temp.columns = ["Error","Beta","Scale","Shape"]
temp.to_csv('COVID/plots/2/res.csv')

# %%
0.20075458852432085 [  0.25083114 107.64419938   3.12462137]
0.19678247689432882 [  0.21519978 117.33243045   3.44531638]
0.20600411620016304 [  0.2686601  103.10788861   2.92904292]
0.1951728507586444 [  0.20925459 119.67574014   3.6143271 ]
0.20684715994410333 [  0.26906006 100.81603878   2.9452714 ]
0.3470650435107239 [ 0.47474559 46.62717385  0.84422198]
0.2103331919291473 [ 0.27879002 99.44954821  2.73698835]
0.1969488923468703 [  0.20330199 121.60889275   3.5532624 ]
0.30040975770140776 [  0.16695965 122.97555155   3.8147839 ]
0.1651128824244584 [  0.22040509 114.92316435   3.48844288]
0.05132766852073145 [  0.23313129 111.21736701   3.4073833 ]
0.37589256654962433 [  0.25680555 102.94400702   3.05811477]
0.19617407349741245 [  0.20400865 121.92469222   3.61244458]
0.15370565240333486 [  0.23538888 111.30444847   3.35023994]
0.15118528276998722 [  0.21791143 114.23066977   3.50980412]
0.13336863939494398 [  0.20752107 121.51545409   3.56264239]
0.08828154983401323 [  0.24581028 103.59973226   3.11806813]
0.0981684899128447 [ 0.27064242 99.94374978  2.92017473]
0.2863322351344771 [  0.22985407 116.09932441   3.33652009]
0.0970404534684281 [  0.2442425  105.88213219   3.20985819]
0.1597277709308679 [  0.18003698 124.7828078    3.83382288]
0.10011021522823765 [  0.17372682 126.26625392   3.80770605]
0.08470956413615618 [  0.25158156 107.60542143   3.11054008]
0.4509669566275275 [  0.18717343 123.22709849   3.73445394]
0.10285288741781592 [  0.23928217 109.36444132   3.30637865]
0.16346502355362624 [  0.26799047 100.3927512    2.93459601]
0.1311467367613795 [  0.20102487 120.20628783   3.69837013]
0.3080374614755087 [  0.16537445 123.40216139   3.82426986]
0.1309759092121744 [  0.21778318 114.29822789   3.50827303]
0.10914775666511989 [  0.23979202 109.11833458   3.29217854]
0.15863050806816545 [  0.2093988  119.34309181   3.58782606]
0.1768726553685434 [  0.19404162 124.54634281   3.66341121]
0.15388996480677436 [  0.19789407 121.67363148   3.60084367]
0.1668610715348357 [ 0.27891004 99.67678326  2.73347314]
0.3509977689809734 [  0.2417781  107.89861382   3.27397385]
0.11151382545102308 [  0.19212667 124.1926544    3.66605651]
0.14446260453632562 [  0.23753164 110.31759059   3.32098475]
0.1378371269412857 [  0.20267868 122.945252     3.60218339]

# %%
## This loss function will be used for the second task
def vis2(parameters,index):
  beta = parameters[0]    ## List of Beta values for all the units - For all the List the size should be 38 X 1
  S0 = parameters[1]      ## List for all units - Susceptible at time t
  E0 = parameters[2]      ## List for all units - Exposed at time t
  I0 = parameters[3]      ## List for all units - Infection at time t
  R0 = parameters[4]      ## List for all units - Recovered at time t
  CIR0 = parameters[5]    ## List for all units - CIR rate at time t. We can take it as a constant - also we can vary it using number of tests
  M = parameters[6]       ## This is the mobility Matrix - This should be of 38 X 38
  N = parameters[7]       ## List for all units - Number of peoples 
  V0 = parameters[8]      ## List for all units - Vaccination % at time t -- Currently we are not using it

  # print(E0)
  # assert(1 == 2)

  epsilon = 0.66 ## Vaccination Efficiency
  alpha = 1 / 5.8 ## Rate from Expose to Infection
  gamma = 1 / 5 ## Rate from Infectioin to Recovered

  ## 1 Nov 2020 to 28 feb. As we have the data for 1 Nov we have to project 119 days more

  S119days = [S0]
  E119days = [E0]
  I119days = [I0]
  R119days = [R0]
  V119days = [V0]
  CIR119days = [CIR0]

  delta_R = [R0]

  ## dVt and dWt we will get from the timeseries data and function respectively

  days = 119 ## From 1 Nov 2020 to 28 feb

  for i in range(days):
    
    CIRcur = CIR119days[i]
    Scur = S119days[i]
    Ecur = E119days[i]
    Icur = I119days[i]
    Rcur = R119days[i]
    Vcur = V119days[i]

    delta_V = vacData[i] ## This we will get from  the data. This is for 38 units
    delta_W = []

    for j in range(38):
      k = i
      wane_population = 0
      while (k >= 0):
        wane_population += delta_R[k][j]*(weibull(i - k + 1 , scale , shape))
        k-=1
      delta_W.append(wane_population)


    Snext, Enext, Inext, Rnext, Vnext = Next_Instant_Values( (beta, Scur, Ecur, Icur, Rcur, CIRcur, M, delta_V, delta_W, N, Vcur) )

    S119days.append(Snext)
    E119days.append(Enext)
    I119days.append(Inext)
    R119days.append(Rnext)
    V119days.append(Vnext)
    delta_R_cur = []

    for j in range(38):
      delta_R_cur.append(Rnext[j] - Rcur[j])

    delta_R.append(delta_R_cur)

    CIRnext = []

    for j in range(38):
      val = CIR0[j] * (testData[0][j] / testData[i+1][j])
      CIRnext.append(val)

    CIR119days.append(CIRnext)
  
  ## Now we have the S,E,I,R values for all the units and for all days from 1 Nov to 28 Feb
  ## Now we will calculate the loss for all units. And we will take the maximum loss
  ## For that i have to calculate the e bar t

  Reported_Cases_Daily = conData ## This we will get from the timeseries data. This should be of size 38X120


  alpha_e_t = [] ## This has the size 38 X 120

  for i in range(38):
    alpha_e_t_unitwise = []
    for j in range(120):
      alpha_e_t_unitwise.append( alpha * E119days[j][i] / CIR119days[j][i] )
    alpha_e_t.append(alpha_e_t_unitwise)
  
  ## We have to take rolling average of the above data

  alpha_e_bar = []

  for i in range(38):
    alpha_e_bar_unitwise = []
    for j in range(120):
      sum = 0
      count = 0
      for k in range(7):
        if(j-k < 0):
          break
        sum += alpha_e_t[i][j-k]
        count+=1
      alpha_e_bar_unitwise.append( sum / count)
    alpha_e_bar.append(alpha_e_bar_unitwise)

  ## Now we have our prediction of daily for each unit
  ## Now we will calcualte the loss for each unit.

  S119days = np.array(S119days)
  E119days = np.array(E119days)
  I119days = np.array(I119days)
  R119days = np.array(R119days)
  V119days = np.array(V119days)
  alpha_e_bar = np.array( alpha_e_bar)
  #Predicted_Case = np.array(Predicted_Case)
  plt.plot(S119days.T[index],label='S')
  plt.plot(E119days.T[index],label='E')
  plt.plot(I119days.T[index],label='I')
  plt.plot(R119days.T[index],label='R')
  plt.plot(V119days.T[index],label='V')
  # # plt.plot(Predicted_Case.T[index],label = 'Predicted')
  # plt.plot(alpha_e_bar[index],label = 'Predicted')
  # plt.plot(conData[1:,index],label = 'True')
  # #plt.plot(S21days.T[index] + E21days.T[index] + I21days.T[index] + R21days.T[index],label = 'Sum')
  plt.legend()
  plt.title(districts[index])
  plt.xlabel('Time from T0')
  plt.ylabel('Count')
  plt.savefig('COVID/plots/2/'+districts[index]+'SEIR.png')
  plt.show()
  return S119days[-1],E119days[-1],I119days[-1],R119days[-1],V119days[-1]

# %%
for index in range(38):
  x0 = 0.1 * np.ones(38)
  M = np.identity(38)
  x0[index] = ans[index][0]
  V0 = np.zeros(38)
  #print(Loss1((x0, S0, I0, E0, R0, CIR0, M, N, V0, ans[index][1],   ans[index][2]),index))
  vis2( (x0, S0, E0, I0, R0, CIR0, M, N, V0, ans[index][1],   ans[index][2]),index)

# %%
V0
# Out:
# array([ 7820020,  3798024, 14385432,  7603420,  6340908, 16614056,
#        10799904,  4676356,  6842812, 12645564, 24992904,  5825932,
#         7626372,  6272888,  3772412,  6792500,  7200164,  9035868,
#        21397572,  8219400, 11837988,  6507424, 10302484,  4761324,
#        10480856,  3977308,  8445196,  6630696,  9428180, 19528732,
#         8622276,  5437800, 11252104, 16967304, 12658636, 10349072,
#        10165152,  3763976])

# %%
# sero2.reset_index(inplace=True)
# # sero2 = sero2.replace('Bagalkote','Bagalakote')
# sero2 = sero2.replace('Belgaum','Belagavi')
# sero2 = sero2.replace('Chamarajanagar','Chamarajanagara')
# sero2= sero2.replace('Chikkaballapur','Chikkaballapura')
# sero2= sero2.replace('Chikmagalur','Chikkamagaluru')
# sero2= sero2.replace('Dakshina-Kannada','Dakshina Kannada')
# sero2= sero2.replace('Uttara-Kannada','Uttara Kannada')
# sero2= sero2.replace('Ramanagar','Ramanagara')
# sero2= sero2.replace('Yadgir','Yadgiri')
# sero2.set_index(["Unit"],inplace=True)

# %%
sero2.to_csv('COVID/serosurvey2.csv')

# %% [markdown]
# # Task3

# %%
#sero2.loc[districts,'S0'] = 1 - (sero2.loc[districts,'E0'] + sero2.loc[districts,'I0']+sero2.loc[districts,'R0'])
sero2['E0'] = 0.05*sero2["Infection"]
sero2['I0'] = 0.95*sero2["Infection"]
sero2

# %%
temp = sero2.loc[districts,['S0','E0','I0','R0','CIR']].values.T
S0,E0,I0,R0,CIR0 = list(temp[0]),list(temp[1]),list(temp[2]),list(temp[3]),list(temp[4])

# %%
for i in range(38):
  E0[i] = E0[i] * N[i]
  I0[i] = I0[i] * N[i]
  R0[i] = R0[i] * N[i]

# %%
start_date = '15-03-2021'#'01-03-2021'#'01-11-2020'#'11-10-2020'
end_date = '07-04-2021'#'28-02-2021'#'01-11-2020'
datesFull = list(mainData['BBMP-West'].index)
datesUsed = datesFull[datesFull.index(start_date):datesFull.index(end_date)+1]
datesLen = datesFull.index(end_date) - datesFull.index(start_date) + 1

# %%
V0 = []
for i in districts:
  V0.append(mainData[i].loc[datesFull[:datesFull.index(start_date)+1],'First'].sum()*0.66)
S0 = N-(np.array(R0)+np.array(I0)+np.array(E0)+np.array(V0))

# %%
testData = []
for i in districts:
  testData.append(list(mainData[i].loc[datesUsed,'TestRoll']))
testData = np.array(testData).T

# %%
conData = []
for i in districts:
  conData.append(list(mainData[i].loc[datesUsed,'ConfirmedRoll']))
conData = np.array(conData).T

# %%
conData.shape
# Out:
# (24, 38)

# %%
vacData = []
for i in districts:
  vacData.append(list(mainData[i].loc[datesUsed,'FirstRoll']))
vacData = np.array(vacData).T

# %%
date = '15-03-2021'#'15-03-2021'
Reported_Cases_On_15_Mar = []
for i in districts:
  Reported_Cases_On_15_Mar.append(mainData[i].loc[date,'ConfirmedRoll'].astype('int32'))

# %%
def Loss3(parameters,index):
  beta = parameters[0]    ## List of Beta values for all the units - For all the List the size should be 38 X 1
  S0 = parameters[1]      ## List for all units - Susceptible at time t
  E0 = parameters[2]      ## List for all units - Exposed at time t
  I0 = parameters[3]      ## List for all units - Infection at time t
  R0 = parameters[4]      ## List for all units - Recovered at time t
  CIR0 = parameters[5]    ## List for all units - CIR rate at time t. We can take it as a constant - also we can vary it using number of tests
  M = parameters[6]       ## This is the mobility Matrix - This should be of 38 X 38
  N = parameters[7]       ## List for all units - Number of peoples 
  V0 = parameters[8]      ## List for all units - Vaccination % at time t -- Currently we are not using it
  scale = parameters[9]
  shape = parameters[10]

  epsilon = 0.66 ## Vaccination Efficiency
  alpha = 1 / 5.8 ## Rate from Expose to Infection
  gamma = 1 / 5 ## Rate from Infectioin to Recovered

  S14days = [S0]
  E14days = [E0]
  I14days = [I0]
  R14days = [R0]
  V14days = [V0]
  CIR14days = [CIR0]

  delta_R = [R0]

  ## dVt and dWt we will get from the timeseries data and function respectively

  days = 14 ## From 11Oct - 31Oct and 1 Nov

  for i in range(14):
    
    '''
      Compute CIR if it is dynamic. Otherwise keep it constant
    '''

    ## print("Day = " , i)

    CIRcur = CIR14days[i]
    
    Scur = S14days[i]
    Ecur = E14days[i]
    Icur = I14days[i]
    Rcur = R14days[i]
    Vcur = V14days[i]

    delta_V = vacData[i]
    delta_W = []

    for j in range(38):
      k = i
      wane_population = 0
      while (k >= 0):
        wane_population += delta_R[k][j]*(weibull(i - k + 1 , scale , shape))
        k-=1
      delta_W.append(wane_population)


    Snext, Enext, Inext, Rnext, Vnext = Next_Instant_Values( (beta, Scur, Ecur, Icur, Rcur, CIRcur, M, delta_V, delta_W, N, Vcur) )

    S14days.append(Snext)
    E14days.append(Enext)
    I14days.append(Inext)
    R14days.append(Rnext)
    V14days.append(Vnext)

    CIRnext = []

    for j in range(38):
      val = CIR0[j] * (testData[0][j] / testData[i][j])
      CIRnext.append(val)

    CIR14days.append(CIRnext)

    delta_R_cur = []

    for j in range(38):
      delta_R_cur.append(Rnext[j] - Rcur[j])

    delta_R.append(delta_R_cur) ## These are the people who went to recovered this day
  
  ## After calculating the 21days values we have to find the loss
  ## Reported_Cases_On_1_Nov = [] ## Find out this from the time series data
  Predicted_Case_On_15_Mar = []

  '''
    For finding the Predicted cases on 1Nov we have to take running avg of past 7 days alpha * e
  '''

  for i in range(38):
    val = 0
    for j in range(7):
      val += alpha * (E14days[-1*j - 1][i] / CIR14days[-1*j - 1][i])
    val /= 7
    Predicted_Case_On_15_Mar.append(val)
  
  ## Now compute the loss
  loss = 0.0
  
  # for i in range(38):
  #   diff = abs(Reported_Cases_On_15_Mar[i] - Predicted_Case_On_15_Mar[i] )/ (Reported_Cases_On_15_Mar[i]+0.01)
  #   loss = max(loss , diff)
  loss = abs( Reported_Cases_On_15_Mar[index] - Predicted_Case_On_15_Mar[index] ) / (Reported_Cases_On_15_Mar[index]+0.01)
  
  return Reported_Cases_On_15_Mar[index] , Predicted_Case_On_15_Mar[index]

  #return loss

# %%
def dummyloss(x): 
  M = np.identity(38)*0.99 + np.ones((38,38))*0.01
  return Loss3((x[:38], S0, E0, I0, R0, CIR0, M, N, V0, x[1], x[2]))

# %%
def dummyloss(x,index): 
  M = np.identity(38)*0.99 + np.ones((38,38))*0.01
  x0 = 0.1 * np.ones(38)
  x0[index] = x[0]
  return Loss3((x0, S0, E0, I0, R0, CIR0, M, N, V0, x[1], x[2]),index)

# %%
def dummyloss2(x,index): 
  M = np.identity(38)*0.99 + np.ones((38,38))*0.01
  x0 = 0.1 * np.ones(38)
  x0[index[0]] = x
  return Loss3( (x0, S0, I0, E0, R0, CIR0, M, N, V0, index[1], index[2]),index[0])

# %%
from scipy.optimize import minimize,brute
x0 = 0.4 * np.ones(3)
x0[1]=105
x0[2]=2.2
# res = minimize(dummyloss, x0,tol=0.1, method='Nelder-Mead')#,bounds=bounds)#'Nelder-Mead'
# print(res.fun,res.x)
# bounds = [(0,1) for _ in range(1)]
# bounds.append((10,200))
# bounds.append((3,5))
# bounds = tuple(bounds)
ans = []

for index in range(38):

  if True:
    res = minimize(dummyloss, x0,index,tol=0.1, method='Nelder-Mead')#,bounds=bounds)#'Nelder-Mead'
    print(res.fun,res.x)
    ans.append(res.x)
    # if res.x[0]<0:
    #   res = minimize(dummyloss2, 0.5,[index,120,3.67],tol=0.1, method='Nelder-Mead')#,bounds=bounds)#'Nelder-Mead'
    #   print(res.fun,res.x)
  # except:
  #   res = minimize(dummyloss2, 0.5,[index,104.57,2.94],tol=0.5, method='Nelder-Mead')#,bounds=bounds)#'Nelder-Mead'
  #   print(res.fun,res.x)
  #   ans.append([res.x[0],104.57,2.94])
# for index in range(38):
#   res = brute(dummyloss,((0,1)),(index))
#   print(res)
#0.45+ for district 6
#0.28 for district 6

# %%
forCSV = [[0.0004998593357918243,6.95121269e-02, 1.27991643e+02, 2.55922243e+00],
[0.00013170314595492926 ,9.00993013e-02 ,1.18714115e+02, 3.22735414e+00],
[0.00037278214049072474 ,6.95875381e-02 ,1.56869320e+02 ,2.68130256e+00],
[0.0009744980755791288 ,5.93887772e-02, 1.22926276e+02 ,3.28855570e+00],
[0.0006964708807419956 ,4.76131759e-02, 1.59515717e+02, 2.72142977e+00],
[0.004009742482693163 ,8.02089946e-02 ,1.28598145e+02 ,3.25905373e+00],
[0.0004688755651123748 ,6.99801472e-02 ,1.26961934e+02, 3.31932499e+00],
[0.00032046478948632133 ,6.85887712e-02, 1.56246454e+02, 2.69589252e+00],
[0.02577074849140526 ,1.69578809e-03 ,1.36260306e+02 ,3.40029080e+00],
[0.016560917226724925 ,3.81839019e-03, 1.35985934e+02, 3.36650029e+00],
[0.014795321412521366 ,9.57220490e-03, 1.35429397e+02, 3.36574741e+00],
[0.001362018118743603 ,1.29747183e-02 ,1.35203300e+02, 3.33520120e+00],
[0.0022810010816940386 ,3.65361256e-02 ,1.55739043e+02, 2.83808534e+00],
[0.009065719868795041 ,1.09512511e-02, 1.35242890e+02 ,3.35412034e+00],
[0.01414653323328319 ,6.71294702e-03 ,1.35346568e+02 ,3.38283760e+00],
[0.03877708880009304 ,6.06612151e-03 ,1.35557681e+02, 3.38326782e+00],
[0.04791561857298121 ,-8.97522331e-04 , 1.26979997e+02,  3.40714760e+00],
[0.01678071323435189 ,5.62312601e-03 ,1.35377771e+02 ,3.38827337e+00],
[0.0023716380082309998 ,2.71637209e-02, 1.35246646e+02, 3.30793170e+00],
[0.12405553903357155 ,-1.71927380e-03 , 1.35943246e+02,  3.41129438e+00],
[0.005083444652245159 ,1.44995642e-03 ,1.26403965e+02, 3.41038906e+00],
[0.01840541870148062 ,4.43341487e-04 ,1.62441632e+02 ,2.84577032e+00],
[0.07743091246253461 ,9.58404146e-04 ,1.35808937e+02 ,3.40436051e+00],
[0.10975524775858375 ,-3.50963173e-03 , 1.36048369e+02,  3.41729696e+00],
[0.0032304125242455066 ,1.24575417e-02, 1.35460348e+02 ,3.30029187e+00],
[0.002936925302450859 ,2.62484701e-02, 1.57740601e+02, 2.84396971e+00],
[0.00396823351693859 ,2.24686322e-02, 1.36637936e+02 ,3.35691471e+00],
[0.20097524931920346 ,-3.65175728e-03,  1.27057300e+02,  3.41727329e+00],
[0.019412771762070076 ,7.81743765e-03, 1.35454697e+02, 3.37118506e+00],
[0.005100046621382169 ,3.58007122e-02, 1.35366819e+02, 3.27046808e+00],
[0.10202125623072134 ,-2.17428858e-03,  1.35960891e+02,  3.41063054e+00],
[0.10375043719555152 ,-9.75366046e-05,  1.35860800e+02,  3.40633351e+00],
[0.044557215918320375 ,1.48556606e-03, 1.35759769e+02, 3.41750554e+00],
[0.002901416530251058 ,1.71798872e-02, 1.35004005e+02, 3.38441609e+00],
[0.000188163583316289 ,1.94121995e-02, 1.24589548e+02, 3.35606861e+00],
[0.003144430491134049 ,3.69848649e-03, 1.62652772e+02, 2.83812974e+00],
[0.048074264671511845 ,3.26500254e-03, 1.35583365e+02, 3.39649400e+00],
[0.17883942529464536 ,-2.19497510e-03,  1.35964756e+02,  3.41175500e+00]]

# %%
# temp = pd.DataFrame(forCSV)
# temp.columns = ["Error","Beta","Scale","Shape"]
# temp["Unit"] = list(map(lambda x:districts[x],temp.index))
# temp.set_index(["Unit"],inplace=True)
# temp.to_csv('COVID/plots/3/ares.csv')

# %%
ans = pd.read_csv('COVID/plots/3/ares.csv',index_col=0).values[:,1:]

# %%
def vis(parameters,index):
  beta = parameters[0]    ## List of Beta values for all the units - For all the List the size should be 38 X 1
  S0 = parameters[1]      ## List for all units - Susceptible at time t
  E0 = parameters[2]      ## List for all units - Exposed at time t
  I0 = parameters[3]      ## List for all units - Infection at time t
  R0 = parameters[4]      ## List for all units - Recovered at time t
  CIR0 = parameters[5]    ## List for all units - CIR rate at time t. We can take it as a constant - also we can vary it using number of tests
  M = parameters[6]       ## This is the mobility Matrix - This should be of 38 X 38
  N = parameters[7]       ## List for all units - Number of peoples 
  V0 = parameters[8]      ## List for all units - Vaccination % at time t -- Currently we are not using it
  scale = parameters[9]
  shape = parameters[10]

  epsilon = 0.66 ## Vaccination Efficiency
  alpha = 1 / 5.8 ## Rate from Expose to Infection
  gamma = 1 / 5 ## Rate from Infectioin to Recovered

  S14days = [S0]
  E14days = [E0]
  I14days = [I0]
  R14days = [R0]
  V14days = [V0]
  CIR14days = [CIR0]

  delta_R = [R0]

  ## dVt and dWt we will get from the timeseries data and function respectively

  days = 14 ## From 11Oct - 31Oct and 1 Nov
  Predicted_Case = []

  for i in range(14):
    
    '''
      Compute CIR if it is dynamic. Otherwise keep it constant
    '''

    ## print("Day = " , i)

    CIRcur = CIR14days[i]
    
    Scur = S14days[i]
    Ecur = E14days[i]
    Icur = I14days[i]
    Rcur = R14days[i]
    Vcur = V14days[i]

    delta_V = vacData[i]
    delta_W = []

    for j in range(38):
      k = i
      wane_population = 0
      while (k >= 0):
        wane_population += delta_R[k][j]*(weibull(i - k + 1 , scale , shape))
        k-=1
      delta_W.append(wane_population)


    Snext, Enext, Inext, Rnext, Vnext = Next_Instant_Values( (beta, Scur, Ecur, Icur, Rcur, CIRcur, M, delta_V, delta_W, N, Vcur) )

    S14days.append(Snext)
    E14days.append(Enext)
    I14days.append(Inext)
    R14days.append(Rnext)
    V14days.append(Vnext)

    CIRnext = []

    for j in range(38):
      val = CIR0[j] * (testData[0][j] / testData[i][j])
      CIRnext.append(val)

    CIR14days.append(CIRnext)

    delta_R_cur = []

    for j in range(38):
      delta_R_cur.append(Rnext[j] - Rcur[j])

    delta_R.append(delta_R_cur) ## These are the people who went to recovered this day
    Predicted_Case_On_1_Nov = []

    for i in range(38):
      Predicted_Case_On_1_Nov.append(alpha * (E14days[- 1][i] / CIR14days[- 1][i]))
    Predicted_Case.append(Predicted_Case_On_1_Nov)
  ## After calculating the 21days values we have to find the loss
  ## Reported_Cases_On_1_Nov = [] ## Find out this from the time series data
  #print(Predicted_Case[-1][index],Reported_Cases_On_15_Mar[index])
  S14days = np.array(S14days)
  E14days = np.array(E14days)
  I14days = np.array(I14days)
  R14days = np.array(R14days)
  V14days = np.array(V14days)
  Predicted_Case = np.array(Predicted_Case)
  # plt.plot(S14days.T[index],label='S')
  # plt.plot(E14days.T[index],label='E')
  # plt.plot(I14days.T[index],label='I')
  # plt.plot(R14days.T[index],label='R')
  # plt.plot(V14days.T[index],label='V')
  plt.plot(Predicted_Case.T[index],label = 'Predicted')
  plt.plot(conData[1:,index],label = 'True')
  # #plt.plot(S21days.T[index] + E21days.T[index] + I21days.T[index] + R21days.T[index],label = 'Sum')
  plt.legend()
  plt.title(districts[index])
  #plt.savefig('COVID/plots/3/1'+districts[index]+'Predicted.png')
  plt.show()
  return S14days[-1][index],E14days[-1][index],I14days[-1][index],R14days[-1][index],V14days[-1][index],CIR14days[-1][index]

# %%
ans=forCSV[:,1:]

# %%
St = np.zeros(38)
Et = np.zeros(38)
It = np.zeros(38)
Rt = np.zeros(38)
Vt = np.zeros(38)
Ct = np.zeros(38)
P,T = [],[]
for index in range(38):
  x0 = 0.1 * np.ones(38)
  M = np.identity(38)*0.99 + np.ones((38,38))*0.01
  x0[index] = ans[index][0]
  #print(Loss1((x0, S0, I0, E0, R0, CIR0, M, N, V0, ans[index][1],   ans[index][2]),index))
  St[index],Et[index],It[index],Rt[index],Vt[index],Ct[index]=vis( (x0, S0, E0, I0, R0, CIR0, M, N, V0, ans[index][1],   ans[index][2]),index)
  #y,x = Loss3( (x0, S0, E0, I0, R0, CIR0, M, N, V0, ans[index][1],   ans[index][2]),index)
#   P.append(x)
#   T.append(y)
# plt.scatter(list(range(38)),T,label='True',marker='*',color='r')
# plt.scatter(list(range(38)),P,label = 'Predicted',marker='+',color='g')
# plt.title('Predicted vs True Values for 15th Mar 2021')
# plt.legend()
# plt.savefig('COVID/plots/3/15thmar2021.png')
# plt.show()

# %%
St,Et,It,Rt,Vt,Ct
# Out:
# (array([ 804968.,  390112., 1480520.,  783392.,  654143., 1707836.,
#         1111467.,  481428., 1832002., 2592690., 4358587.,  882833.,
#          787521., 1649745.,  910684., 1114133.,  866145., 1462908.,
#         1563224., 1763348., 1667159.,  903879., 1467012., 1564292.,
#         2570746.,  405652., 1362734., 1348895., 1453780., 2551578.,
#         1864039.,  922564., 1444060., 2164864.,  859534., 1144212.,
#         2177059., 1267918.]),
#  array([1494., 1002., 2755., 1201.,  774., 3794., 2082.,  877.,  238.,
#          522., 1733.,  484.,  693.,  719.,  267.,  308.,   49.,  385.,
#         1753.,   48.,  216.,   88.,  174.,  -49., 1256.,  426., 1186.,
#          -43.,  478., 3665.,   15.,   70.,  192., 1535.,  698.,  239.,
#          395.,    8.]),
#  array([1774., 1094., 3270., 1505., 1050., 4300., 2467., 1046., 2146.,
#         3302., 6625., 1590., 1042., 2463., 1240., 1540., 1049., 2012.,
#         3972., 1993., 2084., 1113., 1894., 1482., 3993.,  954., 2773.,
#         1343., 2071., 6856., 1832., 1078., 1850., 4264., 1924., 1599.,
#         2699., 1245.]),
#  array([ 30234.,  15075.,  55724.,  29113.,  23931.,  65224.,  41885.,
#          18087.,  72312.,  94403., 202989.,  45537.,  28416.,  44007.,
#          44055.,  43664.,  34672.,  62894.,  91486.,  73598.,  50068.,
#          35954.,  48890.,  37747.,  74433.,  26043.,  67909.,  42647.,
#          91325., 180722.,  59933.,  37011.,  57504.,  85244.,  48173.,
#          43147.,  79868.,  32959.]),
#  array([265652., 129041., 488629., 258279., 215409., 564312., 366851.,
#         158869., 235053., 405561., 784742., 209214., 259059., 206574.,
#         119805., 204626., 234608., 274973., 674712., 263392., 379909.,
#         216045., 322216., 155583., 325973., 127686., 261325., 201277.,
#         303839., 632107., 261631., 179810., 360726., 528160., 396874.,
#         327021., 311790., 110282.]),
#  array([ 5.9807 ,  7.97426,  5.9807 ,  4.98391,  3.98713,  6.97748,
#          5.9807 ,  5.9807 , 23.92279,  9.96783, 38.87453, 11.96139,
#          2.99035, 10.96461, 34.88739, 13.95496,  9.96783, 19.93565,
#         12.95818, 14.95174,  4.98391, 13.95496,  4.98391,  5.9807 ,
#          8.97104, 24.91957, 34.88739,  9.96783, 29.90348, 20.93244,
#         15.94852, 21.92922, 10.96461, 11.96139,  9.96783, 10.96461,
#         22.926  ,  6.97748]))

# %% [markdown]
# # 3b

# %%
## This loss function will be used for the second task for the Task3
def Loss3b(parameters,index):
  beta = parameters[0]    ## List of Beta values for all the units - For all the List the size should be 38 X 1
  S0 = parameters[1]      ## List for all units - Susceptible at time t
  E0 = parameters[2]      ## List for all units - Exposed at time t
  I0 = parameters[3]      ## List for all units - Infection at time t
  R0 = parameters[4]      ## List for all units - Recovered at time t
  CIR0 = parameters[5]    ## List for all units - CIR rate at time t. We can take it as a constant - also we can vary it using number of tests
  M = parameters[6]       ## This is the mobility Matrix - This should be of 38 X 38
  N = parameters[7]       ## List for all units - Number of peoples 
  V0 = parameters[8]      ## List for all units - Vaccination % at time t -- Currently we are not using it

  # print(E0)
  # assert(1 == 2)

  epsilon = 0.66 ## Vaccination Efficiency
  alpha = 1 / 5.8 ## Rate from Expose to Infection
  gamma = 1 / 5 ## Rate from Infectioin to Recovered

  ## 1 Nov 2020 to 28 feb. As we have the data for 1 Nov we have to project 119 days more

  S23days = [S0]
  E23days = [E0]
  I23days = [I0]
  R23days = [R0]
  V23days = [V0]
  CIR23days = [CIR0]

  delta_R = [R0]

  ## dVt and dWt we will get from the timeseries data and function respectively

  days = 23 ## From 1 Nov 2020 to 28 feb

  for i in range(days):
    
    CIRcur = CIR23days[i]
    Scur = S23days[i]
    Ecur = E23days[i]
    Icur = I23days[i]
    Rcur = R23days[i]
    Vcur = V23days[i]

    delta_V = vacData[i] ## This we will get from  the data. This is for 38 units
    delta_W = []

    for j in range(38):
      k = i
      wane_population = 0
      while (k >= 0):
        wane_population += delta_R[k][j]*(weibull(i - k + 1 , scale , shape))
        k-=1
      delta_W.append(wane_population)


    Snext, Enext, Inext, Rnext, Vnext = Next_Instant_Values( (beta, Scur, Ecur, Icur, Rcur, CIRcur, M, delta_V, delta_W, N, Vcur) )

    S23days.append(Snext)
    E23days.append(Enext)
    I23days.append(Inext)
    R23days.append(Rnext)
    V23days.append(Vnext)
    delta_R_cur = []

    for j in range(38):
      delta_R_cur.append(Rnext[j] - Rcur[j])

    delta_R.append(delta_R_cur)

    CIRnext = []

    for j in range(38):
      val = CIR0[j] * (testData[0][j] / testData[i+1][j])
      CIRnext.append(val)

    CIR23days.append(CIRnext)
  
  ## Now we have the S,E,I,R values for all the units and for all days from 1 Nov to 28 Feb
  ## Now we will calculate the loss for all units. And we will take the maximum loss
  ## For that i have to calculate the e bar t

  Reported_Cases_Daily = conData ## This we will get from the timeseries data. This should be of size 38X24


  alpha_e_t = [] ## This has the size 38 X 24

  for i in range(38):
    alpha_e_t_unitwise = []
    for j in range(24):
      # if (E23days[j][i] < 0):
      #   print(S23days[j][i] , E23days[j][i] , I23days[j][i] , R23days[j][i] , V23days[j][i])
      #   assert(1==2)
      alpha_e_t_unitwise.append( alpha * E23days[j][i] / CIR23days[j][i] )
    alpha_e_t.append(alpha_e_t_unitwise)
  
  ## We have to take rolling average of the above data

  alpha_e_bar = []

  for i in range(38):
    alpha_e_bar_unitwise = []
    for j in range(24):
      sum = 0
      count = 0
      for k in range(7):
        if(j-k < 0):
          break
        sum += alpha_e_t[i][j-k]
        count+=1
      alpha_e_bar_unitwise.append( sum / count)
    alpha_e_bar.append(alpha_e_bar_unitwise)

  ## Now we have our prediction of daily for each unit
  ## Now we will calcualte the loss for each unit.

  loss_all_unit = [] ## This will store the loss for all the units
  loss = 0.0 ## This will store the maximum error among the units

  for i in range(38):
    loss_per_unit = 0.0
    for j in range(24):
      ## print(Reported_Cases_Daily[j][i],alpha_e_bar[i][j])
      loss_per_unit += ( math.log( Reported_Cases_Daily[j][index] + 0.0001) - math.log( alpha_e_bar[index][j] )+0.0001 )**2
    ## Also we have to match it to serosurvey data
    ## So, i have to add it to the loss
    loss_per_unit/=24
    #print(loss_per_unit)

    loss_all_unit.append(loss_per_unit)
    #print(loss_per_unit)
    loss = max(loss , loss_per_unit)
  #print(loss_per_unit)
  #print(np.array(E23days)[:,0])
  return loss_per_unit

# %%
def dummyloss(x,index): 
  M = np.identity(38)*0.99 + np.ones((38,38))*0.01
  x0 = 0.04 * np.ones(38)
  x0[index] = x[0]
  return Loss3b( (x0, St, Et, It, Rt, Ct, M, N, V0, x[1], x[2]),index)

# %%
def dummyloss2(x,index): 
  M = np.identity(38)*0.99 + np.ones((38,38))*0.01
  x0 = 0.1 * np.ones(38)
  x0[index[0]] = x
  return Loss3b( (x0, St, Et, It, Rt, Ct, M, N, V0, index[1], index[2]),index[0])

# %%
from scipy.optimize import minimize,brute
x0 = 0.2 * np.ones(3)
x0[1]=200
x0[2]=8 
ans = []
forCSV = []
for index in range(38):
  try:
    res = minimize(dummyloss, x0,index, method='Nelder-Mead')#,bounds=bounds)
    print(res.fun,res.x)
    forCSV.append([res.fun,res.x[0],res.x[1],res.x[2]])
    ans.append(res.x)
  except:
    print('Ignore!!!')
# for index in range(38):
#   res = brute(dummyloss,((0.001,1),(110,130),(3,4)),[index])
#   print(res)
# Out:
# 0.06347021216602101 [ 0.58692 17.52093 -0.53225]
# 0.059066476339214136 [ 0.61389  6.58774 -1.22433]
# 0.06366990837745218 [ 0.58551 17.11508 -0.47149]
# 0.06847467143018668 [ 0.56567 25.92406  0.07365]
# 0.07436094942867869 [ 0.54413 39.65617  0.6224 ]
# 0.061286834496007615 [ 0.59993 11.09693 -0.81968]
# 0.0641285328335412 [ 0.58471 18.90476 -0.43423]
# 0.06225842450368446 [ 0.59175 13.85793 -0.61276]
# 0.25063565081249484 [1.43469e-01 2.17487e+02 8.60131e+00]
# 0.33059420959125446 [1.41043e-01 2.15353e+02 8.67823e+00]
# 0.0857386772119637 [  0.20749 201.7721    7.66724]
# 0.05882946552959605 [ 0.40482 98.34691  3.30904]
# 0.08731523716288625 [ 0.50265 63.16318  1.18888]
# 0.039840972536354886 [  0.3871  108.36117   3.5971 ]
# 0.2642348289189039 [  0.22893 188.89722   7.51692]
# 0.050758880299695906 [1.71375e-01 2.09197e+02 8.25563e+00]
# 0.369447814636753 [  0.24948 179.03052   6.90843]
# 0.1992258715396383 [1.92395e-01 2.07025e+02 7.58522e+00]
# 0.05119099318685066 [  0.3319  139.1372    4.93552]
# 0.3551563570194231 [1.29410e-01 2.21674e+02 8.78134e+00]
# 0.284926376872444 [1.48045e-01 2.12486e+02 8.61187e+00]
# 0.22942962356440547 [1.97797e-01 2.04891e+02 8.01538e+00]
# 0.17289236043356274 [2.03187e-01 2.04704e+02 7.91531e+00]
# Ignore!!!
# 0.03714545643201978 [  0.26465 165.47251   6.42383]
# 0.09846045802817421 [  0.36709 119.0307    4.06115]
# 0.05152332850243225 [  0.35593 141.28995   4.3695 ]
# Ignore!!!
# 0.05425606058576901 [ 0.451   93.03852  2.15935]
# 0.06837528456931939 [  0.37775 113.0469    3.79487]
# 0.4376367289440479 [1.49333e-01 2.10160e+02 8.55430e+00]
# 0.41955721853862826 [1.62147e-01 2.13139e+02 8.30176e+00]
# 0.23222721949621258 [1.83629e-01 2.09179e+02 8.09648e+00]
# 0.1504003384735343 [  0.30735 155.76517   5.46476]
# 0.05140049075380773 [ 0.59737 11.85808 -0.75901]
# 0.5944673641302641 [2.00417e-01 2.02083e+02 8.21667e+00]
# 0.06684832253415143 [  0.24584 178.74853   6.85942]
# Ignore!!!

# %%
ans = pd.read_csv('COVID/plots/3/res.csv',index_col=0).values[:,1:]

# %%
## This loss function will be used for the second task for the Task3
def vis3b(parameters,index):
  beta = parameters[0]    ## List of Beta values for all the units - For all the List the size should be 38 X 1
  S0 = parameters[1]      ## List for all units - Susceptible at time t
  E0 = parameters[2]      ## List for all units - Exposed at time t
  I0 = parameters[3]      ## List for all units - Infection at time t
  R0 = parameters[4]      ## List for all units - Recovered at time t
  CIR0 = parameters[5]    ## List for all units - CIR rate at time t. We can take it as a constant - also we can vary it using number of tests
  M = parameters[6]       ## This is the mobility Matrix - This should be of 38 X 38
  N = parameters[7]       ## List for all units - Number of peoples 
  V0 = parameters[8]      ## List for all units - Vaccination % at time t -- Currently we are not using it

  # print(E0)
  # assert(1 == 2)

  epsilon = 0.66 ## Vaccination Efficiency
  alpha = 1 / 5.8 ## Rate from Expose to Infection
  gamma = 1 / 5 ## Rate from Infectioin to Recovered

  ## 1 Nov 2020 to 28 feb. As we have the data for 1 Nov we have to project 119 days more

  S23days = [S0]
  E23days = [E0]
  I23days = [I0]
  R23days = [R0]
  V23days = [V0]
  CIR23days = [CIR0]

  delta_R = [R0]
  Predicted_Case = []

  ## dVt and dWt we will get from the timeseries data and function respectively

  days = 23 ## From 1 Nov 2020 to 28 feb

  for i in range(days):
    
    CIRcur = CIR23days[i]
    Scur = S23days[i]
    Ecur = E23days[i]
    Icur = I23days[i]
    Rcur = R23days[i]
    Vcur = V23days[i]

    delta_V = vacData[i] ## This we will get from  the data. This is for 38 units
    delta_W = []

    for j in range(38):
      k = i
      wane_population = 0
      while (k >= 0):
        wane_population += delta_R[k][j]*(weibull(i - k + 1 , scale , shape))
        k-=1
      delta_W.append(wane_population)


    Snext, Enext, Inext, Rnext, Vnext = Next_Instant_Values( (beta, Scur, Ecur, Icur, Rcur, CIRcur, M, delta_V, delta_W, N, Vcur) )

    S23days.append(Snext)
    E23days.append(Enext)
    I23days.append(Inext)
    R23days.append(Rnext)
    V23days.append(Vnext)
    delta_R_cur = []

    for j in range(38):
      delta_R_cur.append(Rnext[j] - Rcur[j])

    delta_R.append(delta_R_cur)

    CIRnext = []

    for j in range(38):
      val = CIR0[j] * (testData[0][j] / testData[i+1][j])
      CIRnext.append(val)

    CIR23days.append(CIRnext)
  
  ## Now we have the S,E,I,R values for all the units and for all days from 1 Nov to 28 Feb
  ## Now we will calculate the loss for all units. And we will take the maximum loss
  ## For that i have to calculate the e bar t

  Reported_Cases_Daily = conData ## This we will get from the timeseries data. This should be of size 38X24


  alpha_e_t = [] ## This has the size 38 X 24

  for i in range(38):
    alpha_e_t_unitwise = []
    for j in range(24):
      # if (E23days[j][i] < 0):
      #   print(S23days[j][i] , E23days[j][i] , I23days[j][i] , R23days[j][i] , V23days[j][i])
      #   assert(1==2)
      alpha_e_t_unitwise.append( alpha * E23days[j][i] / (CIR23days[j][i]**2) )
    alpha_e_t.append(alpha_e_t_unitwise)
  
  ## We have to take rolling average of the above data

  alpha_e_bar = []

  for i in range(38):
    alpha_e_bar_unitwise = []
    for j in range(24):
      sum = 0
      count = 0
      for k in range(7):
        if(j-k < 0):
          break
        sum += alpha_e_t[i][j-k]
        count+=1
      alpha_e_bar_unitwise.append( sum / count)
    alpha_e_bar.append(alpha_e_bar_unitwise)

  ## After calculating the 21days values we have to find the loss
  ## Reported_Cases_On_1_Nov = [] ## Find out this from the time series data
  #print(Predicted_Case[-1][index],Reported_Cases_On_15_Mar[index])
  S23days = np.array(S23days)
  E23days = np.array(E23days)
  I23days = np.array(I23days)
  R23days = np.array(R23days)
  V23days = np.array(V23days)
  Predicted_Case = np.array(alpha_e_bar)
  plt.plot(S23days.T[index],label='S')
  plt.plot(E23days.T[index],label='E')
  plt.plot(I23days.T[index],label='I')
  plt.plot(R23days.T[index],label='R')
  plt.plot(V23days.T[index],label='V')
  # plt.plot(Predicted_Case[index],label = 'Predicted')
  # plt.plot(conData[1:,index],label = 'True')
  # #plt.plot(S21days.T[index] + E21days.T[index] + I21days.T[index] + R21days.T[index],label = 'Sum')
  plt.legend()
  plt.title(districts[index])
  #plt.savefig('COVID/plots/3/2'+districts[index]+'SEIR.png')
  plt.show()
  return S23days[-1][index],E23days[-1][index],I23days[-1][index],R23days[-1][index],V23days[-1][index],CIR23days[-1][index]

  ## Now we have our prediction of daily for each unit
  ## Now we will calcualte the loss for each unit.

  #print(loss_per_unit)
  #print(np.array(E23days)[:,0])
  return loss_per_unit

# %%
St2 = np.zeros(38)
Et2 = np.zeros(38)
It2 = np.zeros(38)
Rt2 = np.zeros(38)
Vt2 = np.zeros(38)
Ct2 = np.zeros(38)
P,T = [],[]
index = 0
ct = 0
while index<38:
  if index in [23,27,37]:
    index+=1
    continue
  x0 = 0.1 * np.ones(38)
  M = np.identity(38)*0.99 + np.ones((38,38))*0.01
  x0[index] = ans[ct][0]
  #print(Loss1((x0, S0, I0, E0, R0, CIR0, M, N, V0, ans[index][1],   ans[index][2]),index))
  St2[index],Et2[index],It2[index],Rt2[index],Vt2[index],Ct2[index]=vis3b( (x0, S0, E0, I0, R0, CIR0, M, N, V0, ans[ct][1],   ans[ct][2]),index)
  #y,x = vis( (x0, S0, E0, I0, R0, CIR0, M, N, V0, ans[index][1],   ans[index][2]),index)
  P.append(x)
  T.append(y)
  index+=1
  ct+=1
# plt.scatter(list(range(38)),T,label='True',marker='*',color='r')
# plt.scatter(list(range(38)),P,label = 'Predicted',marker='+',color='g')
# plt.title('Predicted vs True Values for 15th Mar 2021')
# plt.legend()
# plt.savefig('COVID/plots/3/15thmar2021.png')
# plt.show()

# %%
#forCSV# = np.array(forCSV)
# temp = pd.DataFrame(forCSV)
# temp.columns = ["Error","Beta","Scale","Shape"]
#temp.to_csv('COVID/plots/3/res.csv')

# %% [markdown]
# # Task 4

# %%
start_date = '08-04-2021'#'01-03-2021'#'01-11-2020'#'11-10-2020'
end_date = '22-04-2021'#'28-02-2021'#'01-11-2020'
datesFull = list(mainData['BBMP-West'].index)
datesUsed = datesFull[datesFull.index(start_date):datesFull.index(end_date)+1]
datesLen = datesFull.index(end_date) - datesFull.index(start_date) + 1

# %%
testData = []
for i in districts:
  testData.append(list(mainData[i].loc[datesUsed,'TestRoll']))
testData = np.array(testData).T

# %%
conData = []
for i in districts:
  conData.append(list(mainData[i].loc[datesUsed,'ConfirmedRoll']))
conData = np.array(conData).T

# %%
vacData = []
for i in districts:
  vacData.append(list(mainData[i].loc[datesUsed,'FirstRoll']))
vacData = np.array(vacData).T

# %%
St2,Et2,It2,Rt2,Vt2,Ct2

# %%
## This loss function will be used for the second task for the Task3
def Loss4(parameters,index):
  beta = parameters[0]    ## List of Beta values for all the units - For all the List the size should be 38 X 1
  S0 = parameters[1]      ## List for all units - Susceptible at time t
  E0 = parameters[2]      ## List for all units - Exposed at time t
  I0 = parameters[3]      ## List for all units - Infection at time t
  R0 = parameters[4]      ## List for all units - Recovered at time t
  CIR0 = parameters[5]    ## List for all units - CIR rate at time t. We can take it as a constant - also we can vary it using number of tests
  M = parameters[6]       ## This is the mobility Matrix - This should be of 38 X 38
  N = parameters[7]       ## List for all units - Number of peoples 
  V0 = parameters[8]      ## List for all units - Vaccination % at time t -- Currently we are not using it

  # print(E0)
  # assert(1 == 2)

  epsilon = 0.66 ## Vaccination Efficiency
  alpha = 1 / 5.8 ## Rate from Expose to Infection
  gamma = 1 / 5 ## Rate from Infectioin to Recovered

  ## 1 Nov 2020 to 28 feb. As we have the data for 1 Nov we have to project 119 days more

  S23days = [S0]
  E23days = [E0]
  I23days = [I0]
  R23days = [R0]
  V23days = [V0]
  CIR23days = [CIR0]

  delta_R = [R0]

  ## dVt and dWt we will get from the timeseries data and function respectively

  days = 14 ## From 1 Nov 2020 to 28 feb

  for i in range(days):
    
    CIRcur = CIR23days[i]
    Scur = S23days[i]
    Ecur = E23days[i]
    Icur = I23days[i]
    Rcur = R23days[i]
    Vcur = V23days[i]

    delta_V = vacData[i] ## This we will get from  the data. This is for 38 units
    delta_W = []

    for j in range(38):
      k = i
      wane_population = 0
      while (k >= 0):
        wane_population += delta_R[k][j]*(weibull(i - k + 1 , scale , shape))
        k-=1
      delta_W.append(wane_population)


    Snext, Enext, Inext, Rnext, Vnext = Next_Instant_Values( (beta, Scur, Ecur, Icur, Rcur, CIRcur, M, delta_V, delta_W, N, Vcur) )

    S23days.append(Snext)
    E23days.append(Enext)
    I23days.append(Inext)
    R23days.append(Rnext)
    V23days.append(Vnext)
    delta_R_cur = []

    for j in range(38):
      delta_R_cur.append(Rnext[j] - Rcur[j])

    delta_R.append(delta_R_cur)

    CIRnext = []

    for j in range(38):
      val = CIR0[j] * (testData[0][j] / testData[i+1][j])
      CIRnext.append(val)

    CIR23days.append(CIRnext)
  
  ## Now we have the S,E,I,R values for all the units and for all days from 1 Nov to 28 Feb
  ## Now we will calculate the loss for all units. And we will take the maximum loss
  ## For that i have to calculate the e bar t

  Reported_Cases_Daily = conData ## This we will get from the timeseries data. This should be of size 38X24


  alpha_e_t = [] ## This has the size 38 X 24

  for i in range(38):
    alpha_e_t_unitwise = []
    for j in range(15):
      # if (E23days[j][i] < 0):
      #   print(S23days[j][i] , E23days[j][i] , I23days[j][i] , R23days[j][i] , V23days[j][i])
      #   assert(1==2)
      alpha_e_t_unitwise.append( alpha * E23days[j][i] / CIR23days[j][i] )
    alpha_e_t.append(alpha_e_t_unitwise)
  
  ## We have to take rolling average of the above data

  alpha_e_bar = []

  for i in range(38):
    alpha_e_bar_unitwise = []
    for j in range(15):
      sum = 0
      count = 0
      for k in range(7):
        if(j-k < 0):
          break
        sum += alpha_e_t[i][j-k]
        count+=1
      alpha_e_bar_unitwise.append( sum / count)
    alpha_e_bar.append(alpha_e_bar_unitwise)

  ## Now we have our prediction of daily for each unit
  ## Now we will calcualte the loss for each unit.

  loss_all_unit = [] ## This will store the loss for all the units
  loss = 0.0 ## This will store the maximum error among the units

  for i in range(38):
    loss_per_unit = 0.0
    for j in range(15):
      ## print(Reported_Cases_Daily[j][i],alpha_e_bar[i][j])
      loss_per_unit += ( math.log( Reported_Cases_Daily[j][index] + 0.0001) - math.log( alpha_e_bar[index][j] )+0.0001 )**2
    ## Also we have to match it to serosurvey data
    ## So, i have to add it to the loss
    loss_per_unit/=15
    #print(loss_per_unit)

    loss_all_unit.append(loss_per_unit)
    #print(loss_per_unit)
    loss = max(loss , loss_per_unit)
  #print(loss_per_unit)
  #print(np.array(E23days)[:,0])
  return loss_per_unit

# %%
def dummyloss(x,index): 
  M = np.identity(38)#*0.99 + np.ones((38,38))*0.01
  x0 = 0.04 * np.ones(38)
  x0[index] = x[0]
  return Loss4( (x0, St2, Et2, It2, Rt2, Ct2, M, N, V0, x[1], x[2]),index)

# %%
def dummyloss2(x,index): 
  M = np.identity(38)#*0.99 + np.ones((38,38))*0.01
  x0 = 0.1 * np.ones(38)
  x0[index[0]] = x
  return Loss4( (x0, St, Et, It, Rt, Ct, M, N, V0, index[1], index[2]),index[0])

# %%
from scipy.optimize import minimize,brute
x0 = 0.2 * np.ones(3)
x0[1]=200
x0[2]=8 
ans = []
forCSV = []
for index in range(38):
  try:
    res = minimize(dummyloss, x0,index, method='Nelder-Mead')#,bounds=bounds)
    print(res.fun,res.x)
    forCSV.append([res.fun,res.x[0],res.x[1],res.x[2]])
    ans.append(res.x)
  except:
    print('Ignore!!!')
# for index in range(38):
#   res = brute(dummyloss,((0.001,1),(110,130),(3,4)),[index])
#   print(res)
# Out:
# /tmp/ipykernel_4034/898381773.py:93: RuntimeWarning: invalid value encountered in double_scalars
#   alpha_e_t_unitwise.append( alpha * E23days[j][i] / CIR23days[j][i] )
# Ignore!!!
# Ignore!!!
# Ignore!!!
# Ignore!!!
# Ignore!!!
# Ignore!!!
# Ignore!!!
# Ignore!!!
# 0.9331883836770171 [ 0.54273 33.03633  0.62111]
# 1.24381773138312 [ 0.48448 72.1965   1.54362]
# 0.7173460864078353 [1.92550e-01 2.04816e+02 8.06549e+00]
# 0.9404464010450825 [ -0.7367  450.49492  16.4933 ]
# Ignore!!!
# 1.1797740934758898 [-6.51013e-02  2.70192e+02  1.01553e+01]
# 1.7400605222186991 [-3.74219e-02  2.60070e+02  9.49557e+00]
# 2.2758148127446365 [-2.98549e-02  2.58512e+02  9.84925e+00]
# Ignore!!!
# 0.7635941383170921 [ -0.51349 385.69013  14.5916 ]
# Ignore!!!
# 0.7377755293629922 [  0.37828 112.9718    3.85779]
# 0.9914142899127568 [  0.29423 157.34957   5.22164]
# Ignore!!!
# 0.665634781384106 [ -0.72857 446.14089  16.46698]
# nan [  0.2 200.    8. ]
# 1.107959230006996 [7.56586e-02 2.27312e+02 8.95719e+00]
# Ignore!!!
# 1.0201911702159085 [-2.30196e-01  3.10991e+02  1.17617e+01]
# nan [  0.2 200.    8. ]
# 0.5394054638472371 [ -1.32748 620.1352   21.64514]
# 0.6344572629570019 [ -0.82551 474.30004  17.35799]
# 0.8576353543863635 [  0.3577  135.56956   4.3542 ]
# Ignore!!!
# 1.0109400877631323 [  0.30335 155.67901   5.04938]
# 0.10050526616263289 [ -2.1617  810.61788  29.52381]
# Ignore!!!
# Ignore!!!
# 1.3079230288268275 [  0.2368  184.08231   7.35623]
# nan [  0.2 200.    8. ]

# %%
## This loss function will be used for the second task for the Task3
def vis4(parameters,index):
  beta = parameters[0]    ## List of Beta values for all the units - For all the List the size should be 38 X 1
  S0 = parameters[1]      ## List for all units - Susceptible at time t
  E0 = parameters[2]      ## List for all units - Exposed at time t
  I0 = parameters[3]      ## List for all units - Infection at time t
  R0 = parameters[4]      ## List for all units - Recovered at time t
  CIR0 = parameters[5]    ## List for all units - CIR rate at time t. We can take it as a constant - also we can vary it using number of tests
  M = parameters[6]       ## This is the mobility Matrix - This should be of 38 X 38
  N = parameters[7]       ## List for all units - Number of peoples 
  V0 = parameters[8]      ## List for all units - Vaccination % at time t -- Currently we are not using it

  # print(E0)
  # assert(1 == 2)

  epsilon = 0.66 ## Vaccination Efficiency
  alpha = 1 / 5.8 ## Rate from Expose to Infection
  gamma = 1 / 5 ## Rate from Infectioin to Recovered

  ## 1 Nov 2020 to 28 feb. As we have the data for 1 Nov we have to project 119 days more

  S23days = [S0]
  E23days = [E0]
  I23days = [I0]
  R23days = [R0]
  V23days = [V0]
  CIR23days = [CIR0]

  delta_R = [R0]

  ## dVt and dWt we will get from the timeseries data and function respectively

  days = 14 ## From 1 Nov 2020 to 28 feb

  for i in range(days):
    
    CIRcur = CIR23days[i]
    Scur = S23days[i]
    Ecur = E23days[i]
    Icur = I23days[i]
    Rcur = R23days[i]
    Vcur = V23days[i]

    delta_V = vacData[i] ## This we will get from  the data. This is for 38 units
    delta_W = []

    for j in range(38):
      k = i
      wane_population = 0
      while (k >= 0):
        wane_population += delta_R[k][j]*(weibull(i - k + 1 , scale , shape))
        k-=1
      delta_W.append(wane_population)


    Snext, Enext, Inext, Rnext, Vnext = Next_Instant_Values( (beta, Scur, Ecur, Icur, Rcur, CIRcur, M, delta_V, delta_W, N, Vcur) )

    S23days.append(Snext)
    E23days.append(Enext)
    I23days.append(Inext)
    R23days.append(Rnext)
    V23days.append(Vnext)
    delta_R_cur = []

    for j in range(38):
      delta_R_cur.append(Rnext[j] - Rcur[j])

    delta_R.append(delta_R_cur)

    CIRnext = []

    for j in range(38):
      val = CIR0[j] * (testData[0][j] / testData[i+1][j])
      CIRnext.append(val)

    CIR23days.append(CIRnext)
  
  ## Now we have the S,E,I,R values for all the units and for all days from 1 Nov to 28 Feb
  ## Now we will calculate the loss for all units. And we will take the maximum loss
  ## For that i have to calculate the e bar t

  Reported_Cases_Daily = conData ## This we will get from the timeseries data. This should be of size 38X24


  alpha_e_t = [] ## This has the size 38 X 24

  for i in range(38):
    alpha_e_t_unitwise = []
    for j in range(15):
      # if (E23days[j][i] < 0):
      #   print(S23days[j][i] , E23days[j][i] , I23days[j][i] , R23days[j][i] , V23days[j][i])
      #   assert(1==2)
      alpha_e_t_unitwise.append( alpha * E23days[j][i] / CIR23days[j][i] )
    alpha_e_t.append(alpha_e_t_unitwise)
  
  ## We have to take rolling average of the above data

  alpha_e_bar = []

  for i in range(38):
    alpha_e_bar_unitwise = []
    for j in range(15):
      sum = 0
      count = 0
      for k in range(7):
        if(j-k < 0):
          break
        sum += alpha_e_t[i][j-k]
        count+=1
      alpha_e_bar_unitwise.append( sum / count)
    alpha_e_bar.append(alpha_e_bar_unitwise)

  ## Now we have our prediction of daily for each unit
  ## Now we will calcualte the loss for each unit.

  loss_all_unit = [] ## This will store the loss for all the units
  loss = 0.0 ## This will store the maximum error among the units

  for i in range(38):
    loss_per_unit = 0.0
    for j in range(15):
      ## print(Reported_Cases_Daily[j][i],alpha_e_bar[i][j])
      loss_per_unit += ( math.log( Reported_Cases_Daily[j][index] + 0.0001) - math.log( alpha_e_bar[index][j] )+0.0001 )**2
    ## Also we have to match it to serosurvey data
    ## So, i have to add it to the loss
    loss_per_unit/=15
    #print(loss_per_unit)

    loss_all_unit.append(loss_per_unit)
    #print(loss_per_unit)
    loss = max(loss , loss_per_unit)
  #print(loss_per_unit)
  #print(np.array(E23days)[:,0])
  S23days = np.array(S23days)
  E23days = np.array(E23days)
  I23days = np.array(I23days)
  R23days = np.array(R23days)
  V23days = np.array(V23days)
  Predicted_Case = np.array(alpha_e_bar)
  # plt.plot(S23days.T[index],label='S')
  # plt.plot(E23days.T[index],label='E')
  # plt.plot(I23days.T[index],label='I')
  # plt.plot(R23days.T[index],label='R')
  # plt.plot(V23days.T[index],label='V')
  plt.plot(Predicted_Case[index],label = 'Predicted')
  plt.plot(conData[1:,index],label = 'True')
  # #plt.plot(S21days.T[index] + E21days.T[index] + I21days.T[index] + R21days.T[index],label = 'Sum')
  plt.legend()
  plt.title(districts[index])
  #plt.savefig('COVID/plots/3/2'+districts[index]+'SEIR.png')
  plt.show()
  return S23days[-1][index],E23days[-1][index],I23days[-1][index],R23days[-1][index],V23days[-1][index],CIR23days[-1][index]

  return loss_per_unit

# %%
conData.shape
# Out:
# (15, 38)

# %%
St3 = np.zeros(38)
Et3 = np.zeros(38)
It3 = np.zeros(38)
Rt3 = np.zeros(38)
Vt3 = np.zeros(38)
Ct3 = np.zeros(38)
P,T = [],[]
index = 0
ct = 0
while index<38:
  if index in [0,1,2,3,4,5,6,7,12,16,18,21,25,31,34,35,23,27,37]:
    index+=1
    continue
  x0 = 0.1 * np.ones(38)
  M = np.identity(38)#*0.99 + np.ones((38,38))*0.01
  x0[index] = ans[ct][0]
  #print(Loss1((x0, S0, I0, E0, R0, CIR0, M, N, V0, ans[index][1],   ans[index][2]),index))
  St3[index],Et3[index],It3[index],Rt3[index],Vt3[index],Ct3[index]=vis4( (x0, S0, E0, I0, R0, CIR0, M, N, V0, ans[ct][1],   ans[ct][2]),index)
  #y,x = vis( (x0, S0, E0, I0, R0, CIR0, M, N, V0, ans[index][1],   ans[index][2]),index)
  P.append(x)
  T.append(y)
  index+=1
  ct+=1
# plt.scatter(list(range(38)),T,label='True',marker='*',color='r')
# plt.scatter(list(range(38)),P,label = 'Predicted',marker='+',color='g')
# plt.title('Predicted vs True Values for 15th Mar 2021')
# plt.legend()
# plt.savefig('COVID/plots/3/15thmar2021.png')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4034/1795487621.py in <module>
#      16   x0[index] = ans[ct][0]
#      17   #print(Loss1((x0, S0, I0, E0, R0, CIR0, M, N, V0, ans[index][1],   ans[index][2]),index))
# ---> 18   St3[index],Et3[index],It3[index],Rt3[index],Vt3[index],Ct3[index]=vis4( (x0, S0, E0, I0, R0, CIR0, M, N, V0, ans[ct][1],   ans[ct][2]),index)
#      19   #y,x = vis( (x0, S0, E0, I0, R0, CIR0, M, N, V0, ans[index][1],   ans[index][2]),index)
#      20   P.append(x)
#
# /tmp/ipykernel_4034/3475964881.py in vis4(parameters, index)
#     121     for j in range(15):
#     122       ## print(Reported_Cases_Daily[j][i],alpha_e_bar[i][j])
# --> 123       loss_per_unit += ( math.log( Reported_Cases_Daily[j][index] + 0.0001) - math.log( alpha_e_bar[index][j] )+0.0001 )**2
#     124     ## Also we have to match it to serosurvey data
#     125     ## So, i have to add it to the loss
#
# ValueError: math domain error

# %%
forCSV = np.array(forCSV)
temp = pd.DataFrame(forCSV)
temp.columns = ["Error","Beta","Scale","Shape"]
temp.to_csv('COVID/plots/4/res.csv')

# %% [markdown]
# # Tak 5

# %%
St2,Et2,It2,Rt2,Vt2,Ct2

# %%
## This loss function will be used for the second task for the Task3
def Loss5(parameters,index):
  beta = parameters[0]    ## List of Beta values for all the units - For all the List the size should be 38 X 1
  S0 = parameters[1]      ## List for all units - Susceptible at time t
  E0 = parameters[2]      ## List for all units - Exposed at time t
  I0 = parameters[3]      ## List for all units - Infection at time t
  R0 = parameters[4]      ## List for all units - Recovered at time t
  CIR0 = parameters[5]    ## List for all units - CIR rate at time t. We can take it as a constant - also we can vary it using number of tests
  M = parameters[6]       ## This is the mobility Matrix - This should be of 38 X 38
  N = parameters[7]       ## List for all units - Number of peoples 
  V0 = parameters[8]      ## List for all units - Vaccination % at time t -- Currently we are not using it

  # print(E0)
  # assert(1 == 2)

  epsilon = 0.66 ## Vaccination Efficiency
  alpha = 1 / 5.8 ## Rate from Expose to Infection
  gamma = 1 / 5 ## Rate from Infectioin to Recovered

  ## 1 Nov 2020 to 28 feb. As we have the data for 1 Nov we have to project 119 days more

  S23days = [S0]
  E23days = [E0]
  I23days = [I0]
  R23days = [R0]
  V23days = [V0]
  CIR23days = [CIR0]

  delta_R = [R0]

  ## dVt and dWt we will get from the timeseries data and function respectively

  days = 23 ## From 1 Nov 2020 to 28 feb

  for i in range(days):
    
    CIRcur = CIR23days[i]
    Scur = S23days[i]
    Ecur = E23days[i]
    Icur = I23days[i]
    Rcur = R23days[i]
    Vcur = V23days[i]

    delta_V = vacData[i] ## This we will get from  the data. This is for 38 units
    delta_W = []

    for j in range(38):
      k = i
      wane_population = 0
      while (k >= 0):
        wane_population += delta_R[k][j]*(weibull(i - k + 1 , scale , shape))
        k-=1
      delta_W.append(wane_population)


    Snext, Enext, Inext, Rnext, Vnext = Next_Instant_Values( (beta, Scur, Ecur, Icur, Rcur, CIRcur, M, delta_V, delta_W, N, Vcur) )

    S23days.append(Snext)
    E23days.append(Enext)
    I23days.append(Inext)
    R23days.append(Rnext)
    V23days.append(Vnext)
    delta_R_cur = []

    for j in range(38):
      delta_R_cur.append(Rnext[j] - Rcur[j])

    delta_R.append(delta_R_cur)

    CIRnext = []

    for j in range(38):
      val = CIR0[j] * (testData[0][j] / testData[i+1][j])
      CIRnext.append(val)

    CIR23days.append(CIRnext)
  
  ## Now we have the S,E,I,R values for all the units and for all days from 1 Nov to 28 Feb
  ## Now we will calculate the loss for all units. And we will take the maximum loss
  ## For that i have to calculate the e bar t

  Reported_Cases_Daily = conData ## This we will get from the timeseries data. This should be of size 38X24


  alpha_e_t = [] ## This has the size 38 X 24

  for i in range(38):
    alpha_e_t_unitwise = []
    for j in range(24):
      # if (E23days[j][i] < 0):
      #   print(S23days[j][i] , E23days[j][i] , I23days[j][i] , R23days[j][i] , V23days[j][i])
      #   assert(1==2)
      alpha_e_t_unitwise.append( alpha * E23days[j][i] / CIR23days[j][i] )
    alpha_e_t.append(alpha_e_t_unitwise)
  
  ## We have to take rolling average of the above data

  alpha_e_bar = []

  for i in range(38):
    alpha_e_bar_unitwise = []
    for j in range(24):
      sum = 0
      count = 0
      for k in range(7):
        if(j-k < 0):
          break
        sum += alpha_e_t[i][j-k]
        count+=1
      alpha_e_bar_unitwise.append( sum / count)
    alpha_e_bar.append(alpha_e_bar_unitwise)

  ## Now we have our prediction of daily for each unit
  ## Now we will calcualte the loss for each unit.

  loss_all_unit = [] ## This will store the loss for all the units
  loss = 0.0 ## This will store the maximum error among the units

  for i in range(38):
    loss_per_unit = 0.0
    for j in range(24):
      ## print(Reported_Cases_Daily[j][i],alpha_e_bar[i][j])
      loss_per_unit += ( math.log( Reported_Cases_Daily[j][index] + 0.0001) - math.log( alpha_e_bar[index][j] )+0.0001 )**2
    ## Also we have to match it to serosurvey data
    ## So, i have to add it to the loss
    loss_per_unit/=24
    #print(loss_per_unit)

    loss_all_unit.append(loss_per_unit)
    #print(loss_per_unit)
    loss = max(loss , loss_per_unit)
  #print(loss_per_unit)
  #print(np.array(E23days)[:,0])
  return loss_per_unit

# %%
def dummyloss(x,index): 
  M = np.identity(38)#*0.99 + np.ones((38,38))*0.01
  x0 = 0.04 * np.ones(38)
  x0[index] = x[0]
  return Loss5( (x0, St2, Et2, It2, Rt2, Ct2, M, N, V0, x[1], x[2]),index)

# %%
def dummyloss2(x,index): 
  M = np.identity(38)#*0.99 + np.ones((38,38))*0.01
  x0 = 0.1 * np.ones(38)
  x0[index[0]] = x
  return Loss5( (x0, St, Et, It, Rt, Ct, M, N, V0, index[1], index[2]),index[0])

# %%
from scipy.optimize import minimize,brute
x0 = 0.2 * np.ones(3)
x0[1]=200
x0[2]=8 
ans = []
forCSV = []
for index in range(38):
  try:
    res = minimize(dummyloss, x0,index, method='Nelder-Mead')#,bounds=bounds)
    print(res.fun,res.x)
    forCSV.append([res.fun,res.x[0],res.x[1],res.x[2]])
    ans.append(res.x)
  except:
    print('Ignore!!!')
# for index in range(38):
#   res = brute(dummyloss,((0.001,1),(110,130),(3,4)),[index])
#   print(res)
# Out:
# /tmp/ipykernel_4034/1163910556.py:93: RuntimeWarning: invalid value encountered in double_scalars
#   alpha_e_t_unitwise.append( alpha * E23days[j][i] / CIR23days[j][i] )
# Ignore!!!
# Ignore!!!
# Ignore!!!
# Ignore!!!
# Ignore!!!
# Ignore!!!
# Ignore!!!
# Ignore!!!
# Ignore!!!
# Ignore!!!
# 3.417777061659425 [1.33307e-01 2.26230e+02 8.54540e+00]
# Ignore!!!
# Ignore!!!
# Ignore!!!
# Ignore!!!
# Ignore!!!
# Ignore!!!
# Ignore!!!
# Ignore!!!
# 4.311449083229502 [1.78632e-01 2.09805e+02 8.41333e+00]
# Ignore!!!
# Ignore!!!
# Ignore!!!
# nan [  0.2 200.    8. ]
# 1.1634918357410877 [  0.3252  143.31069   5.06586]
# Ignore!!!
# Ignore!!!
# nan [  0.2 200.    8. ]
# Ignore!!!
# Ignore!!!
# 5.6838815183746005 [  0.20561 196.3813    7.80963]
# Ignore!!!
# Ignore!!!
# Ignore!!!
# Ignore!!!
# Ignore!!!
# Ignore!!!
# nan [  0.2 200.    8. ]

# %%
forCSV = np.array(forCSV)
temp = pd.DataFrame(forCSV)
temp.columns = ["Error","Beta","Scale","Shape"]
temp.to_csv('COVID/plots/5/res.csv')

# %%
# for i in ['1','2','3']:
#   temp = pd.read_csv('COVID/plots/'+i+'/res.csv',index_col=0)
#   temp["Unit"] = list(map(lambda x: districts[x],temp.index))
#   temp.set_index(["Unit"],inplace=True)
#   temp.to_csv('COVID/plots/'+i+'/res.csv')
